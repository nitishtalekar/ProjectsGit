# %%
import requests

# %%
r = requests.get("https://mangafast.net/bleach-chapter-641/")
print(r.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" itemscope="itemscope" itemtype="https://schema.org/WebPage">
# 	<head profile="https://gmpg.org/xfn/11">
# 	    <meta charset="utf-8">
# 		<meta http-equiv="content-type" content="text/html; charset=utf-8"/>
# 		<meta name="viewport" content="width=device-width" />
# 		<link rel="canonical" href="https://mangafast.net/bleach-chapter-641/" />
# 		<link rel="alternate" href="https://mangafast.net/bleach-chapter-641/" hreflang="x-default" />
# 		<link rel="alternate" href="https://mangafast.net/bleach-chapter-641/" hreflang="en" />
# 		<meta name="robots" content="noodp">
# 		<title>Bleach Chapter 641 English - Mangafast</title>
# 		<meta name="description" content=">Read Bleach Chapter 641 in English. Bleach Manga available for free at Mangafast." />
# 		<meta name="keywords" itemprop="keywords" content="Bleach Chapter 641, Bleach Manga, read Bleach, Bleach Online, Bleach English" />
# ...

# %%
html = r.text

# %%
x = html.split(' ')
y = []
for i in x:
    if "jpg" in i and "src" in i and "cdn" in i:
#         print(i)
        y.append(i[5:-1])
y
# Out:
# ['https://cdn.statically.io/img/img.y7349.top/img/c/bleach/chapter-641/bleach-chapter-641-page-1.jpg',
#  'https://cdn.statically.io/img/img.y7349.top/img/c/bleach/chapter-641/bleach-chapter-641-page-2.jpg',
#  'https://cdn.statically.io/img/img.y7349.top/img/c/bleach/chapter-641/bleach-chapter-641-page-3.jpg',
#  'https://cdn.statically.io/img/img.y7349.top/img/c/bleach/chapter-641/bleach-chapter-641-page-4.jpg',
#  'https://cdn.statically.io/img/img.y7349.top/img/c/bleach/chapter-641/bleach-chapter-641-page-5.jpg',
#  'https://cdn.statically.io/img/img.y7349.top/img/c/bleach/chapter-641/bleach-chapter-641-page-6.jpg',
#  'https://cdn.statically.io/img/img.y7349.top/img/c/bleach/chapter-641/bleach-chapter-641-page-7.jpg',
#  'https://cdn.statically.io/img/img.y7349.top/img/c/bleach/chapter-641/bleach-chapter-641-page-8.jpg',
#  'https://cdn.statically.io/img/img.y7349.top/img/c/bleach/chapter-641/bleach-chapter-641-page-9.jpg',
# ...

# %%
import requests
for pg in range(len(y)):
    f = open(str(pg)+'.jpg','wb')
    f.write(requests.get(y[pg]).content)
    f.close()

# %%
filenames = [str(i)+".jpg" for i in range(len(y))]
filenames
# Out:
# ['0.jpg',
#  '1.jpg',
#  '2.jpg',
#  '3.jpg',
#  '4.jpg',
#  '5.jpg',
#  '6.jpg',
#  '7.jpg',
#  '8.jpg',
#  '9.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.jpg',
#  '17.jpg',
#  '18.jpg',
#  '19.jpg',
#  '20.jpg']

# %%
from fpdf import FPDF
pdf = FPDF()
# imagelist is the list with all image filenames
for image in filenames:
    pdf.add_page()
    pdf.image(image)
pdf.output("yourfile.pdf", "F")
print("Done")
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~\Applictions\Anaconda3\lib\site-packages\fpdf\fpdf.py in _parsejpg(self, filename)
#    1719                 if markerHigh != 0xFF or markerLow < 0xC0:
# -> 1720                     raise SyntaxError('No JPEG marker found')
#    1721                 elif markerLow == 0xDA: # SOS
#
# SyntaxError: No JPEG marker found
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-35-27fe30d424f2> in <module>()
#       4 for image in filenames:
#       5     pdf.add_page()
# ----> 6     pdf.image(image)
#       7 pdf.output("yourfile.pdf", "F")
#       8 print("Done")
#
# ~\Applictions\Anaconda3\lib\site-packages\fpdf\fpdf.py in wrapper(self, *args, **kwargs)
# ...

# %%
from PIL import Image

im_list = []

for i in filenames:
    im_list.append(Image.open(i))

im1 = Image.open("0.jpg")
# im2 = Image.open("/Users/apple/Desktop/bbd1.jpg")
# im3 = Image.open("/Users/apple/Desktop/bbd2.jpg")
# im_list = [im2,im3]

pdf1_filename = "bbd1.pdf"

im1.save(pdf1_filename, "PDF" ,resolution=100.0, save_all=True, append_images=im_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-8ad91743d844> in <module>()
#       2
#       3 for i in filenames:
# ----> 4     im_list.append(Image.open(i))
#       5
#       6 im1 = Image.open("0.jpg")
#
# NameError: name 'im_list' is not defined
