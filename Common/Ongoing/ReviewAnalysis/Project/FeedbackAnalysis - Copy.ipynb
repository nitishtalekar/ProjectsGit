# %% [markdown]
# # IMPORTS

# %%
import re
from nltk.tokenize import word_tokenize
from string import punctuation 
import nltk
# nltk.download('stopwords')
# nltk.download('punkt')
from nltk.corpus import stopwords
from nltk import punkt
import random as r
import pymysql

# %% [markdown]
# # DATA

# %%
import csv

input_file = csv.DictReader(open("review_data_sentiment.csv",encoding='cp850'))
data = []
k = 0
for i in input_file:
    data.append(dict(i))

x = round(0.8*(len(data)))
data2 = data[:]

train_data = r.sample(data, x)
for i in train_data:
    data2.remove(i)
test_data = data2[:]

print("TRAIN DATA")
print(len(train_data))
print("TEST DATA")
print(len(test_data))
# type(input_file)
# Out:
# TRAIN DATA
# 21230
# TEST DATA
# 5308

# %% [markdown]
# # MODEL

# %%
class PreProcessReviews:
    def __init__(self):
        self._stopwords = set(stopwords.words('english') + list(punctuation) + ['AT_USER','URL'])
        
    def processReviews(self, list_of_reviews):
        processedReviews=[]
            
        for review in list_of_reviews:
            processedReviews.append((self._processReview(review["text"]),review["sentiment"]))
        return processedReviews
    
    def _processReview(self, review):
        review = review.lower() # convert text to lower-case
        review = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', review) # remove URLs
        review = re.sub('@[^\s]+', 'AT_USER', review) # remove usernames
        review = re.sub(r'#([^\s]+)', r'\1', review) # remove the # in #hashtag
        review = word_tokenize(review) # remove repeated characters (helloooooooo into hello)
        return [word for word in review if word not in self._stopwords]
    
reviewProcessor = PreProcessReviews()
preprocessedTrainingSet = reviewProcessor.processReviews(train_data)
print(preprocessedTrainingSet[0])
def buildVocabulary(preprocessedTrainingData):
    all_words = []
    
    for (words, sentiment) in preprocessedTrainingData:
        all_words.extend(words)

    wordlist = nltk.FreqDist(all_words)
    word_features = wordlist.keys()
    
    return word_features
def extract_features(review):
    review_words = set(review)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in review_words)
    return features

word_features = buildVocabulary(preprocessedTrainingSet)
trainingFeatures = nltk.classify.apply_features(extract_features, preprocessedTrainingSet)
print(trainingFeatures[:5])
print(word_features[:5])
# Out:
# (['others', 'said', 'reviews', 'fantastic', 'cable', '...', 'right', 'point', 'stops', 'working', 'delivered', 'july', '10th', 'september', '21st', 'started', 'show', 'signs', 'shorting', 'two', 'days', 'later', 'completely', 'useless', 'would', "n't", 'recommend', 'anyone', 'going', 'purchase', 'item', 'skiva'], 'F')
# [({'contains(others)': True, 'contains(said)': True, 'contains(reviews)': True, 'contains(fantastic)': True, 'contains(cable)': True, 'contains(...)': True, 'contains(right)': True, 'contains(point)': True, 'contains(stops)': True, 'contains(working)': True, 'contains(delivered)': True, 'contains(july)': True, 'contains(10th)': True, 'contains(september)': True, 'contains(21st)': True, 'contains(started)': True, 'contains(show)': True, 'contains(signs)': True, 'contains(shorting)': True, 'contains(two)': True, 'contains(days)': True, 'contains(later)': True, 'contains(completely)': True, 'contains(useless)': True, 'contains(would)': True, "contains(n't)": True, 'contains(recommend)': True, 'contains(anyone)': True, 'contains(going)': True, 'contains(purchase)': True, 'contains(item)': True, 'contains(skiva)': True, "contains('ve)": False, 'contains(used)': False, 'contains(many)': False, 'contains(cased)': False, 'contains(far)': False, 'contains(one)': False, 'contains(worst)': False, 'contains(iphone)': False, 'contains(cases)': False, 'contains(ever)': False, 'contains(seen)': False, 'contains(first)': False, 'contains(question)': False, 'contains(put)': False, 'contains(gave)': False, 'contains(putting)': False, 'contains(since)': False, "contains('s)": False, 'contains(darn)': False, 'contains(hard)': False, 'contains(plastic)': False, 'contains(suppose)': False, 'contains(hold)': False, 'contains(inside)': False, 'contains(really)': False, 'contains(cheaply)': False, 'contains(made)': False, 'contains(lot)': False, 'contains(edges)': False, 'contains(think)': False, 'contains(good)': False, 'contains(idea)': False, 'contains(expensive)': False, 'contains(phone)': False, 'contains(anyway)': False, 'contains(something)': False, "contains('m)": False, 'contains(risk)': False, 'contains(find)': False, 'contains(whether)': False, 'contains(protect)': False, 'contains(without)': False, 'contains(damaging)': False, 'contains(took)': False, 'contains(almost)': False, 'contains(6)': False, 'contains(weeks)': False, 'contains(get)': False, 'contains(live)': False, 'contains(la)': False, 'contains(product)': False, 'contains(shipping)': False, 'contains(method)': False, 'contains(interferes)': False, 'contains(reception)': False, 'contains(case)': False, "contains('d)": False, 'contains(1)': False, 'contains(bar)': False, "contains('searching)": False, 'contains(texts)': False, 'contains(2)': False, 'contains(hours)': False, 'contains(plus)': False, 'contains(use)': False, 'contains(hair)': False, 'contains(clip)': False, 'contains(lol)': False, 'contains(doubt)': False, "contains('ll)": False, 'contains(maybe)': False, 'contains(want)': False, 'contains(everyone)': False, 'contains(ignore)': False, 'contains(bought)': False, 'contains(ipod)': False, 'contains(nano)': False, 'contains(unfortunately)': False, 'contains(worked)': False, 'contains(say)': False, 'contains(pay)': False, 'contains(true)': False, 'contains(even)': False, 'contains(low)': False, 'contains(price)': False, 'contains(couple)': False, 'contains(fiancee)': False, 'contains(family)': False, 'contains(members)': False, 'contains(color)': False, 'contains(choices)': False, 'contains(quality)': False, 'contains(never)': False, 'contains(issues)': False, 'contains(works)': False, 'contains(well)': False, 'contains(wonderful)': False, 'contains(protection)': False, 'contains(super)': False, 'contains(dropped)': False, 'contains(glad)': False, 'contains(cover)': False, 'contains(jackery)': False, 'contains(giants+)': False, 'contains(12000mah)': False, 'contains(charge)': False, 'contains(ipad/tablet)': False, 'contains(bluetooth)': False, 'contains(speaker)': False, 'contains(personally)': False, 'contains(modern)': False, 'contains(era)': False, 'contains(power)': False, 'contains(bank)': False, 'contains(gadgets)': False, 'contains(choose)': False, 'contains(allows)': False, 'contains(simultaneously)': False, 'contains(devices)': False, 'contains(outputs)': False,  ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-735a54b11cff> in <module>
#      41 trainingFeatures = nltk.classify.apply_features(extract_features, preprocessedTrainingSet)
#      42 print(trainingFeatures[:5])
# ---> 43 print(word_features[:5])
#
# TypeError: 'dict_keys' object is not subscriptable

# %% [markdown]
# # TRAINING

# %%
NBayesClassifier = nltk.NaiveBayesClassifier.train(trainingFeatures)
print(NBayesClassifier)
# Out:
# <nltk.classify.naivebayes.NaiveBayesClassifier object at 0x000000523C38AC18>

# %%
import pickle
f = open('NBClassifier_1', 'wb')
pickle.dump(NBayesClassifier, f)
f.close()

# %% [markdown]
# # TESTING

# %%
preprocessedTestingSet = reviewProcessor.processReviews(test_data)
test = []
result = []
for i in range(len(data)-x):
    t = r.choice(preprocessedTestingSet)
    preprocessedTestingSet.remove(t)
    test.append(t[0])
    result.append(t[1])
# print(test)
# print(result)
k = 0
p = 0
for i in test:
    NB = NBayesClassifier.classify(extract_features(i))
#     print(NB," ",result[k])
    if NB == result[k]:
        p = p + 1
    k = k + 1
accuracy = p*100/k
print("ACCURACY =")
print(accuracy)
# Out:
# ACCURACY =
# 84.8153730218538

# %% [markdown]
# # DATABASE

# %%
import pymysql
conn = pymysql.connect(host="localhost",user="root",passwd="",db="fake_feedback")
cur = conn.cursor()
print("Database Connected")

try:
    d = "select * from reviews"
    cur.execute(d)
    review_data = cur.fetchall()
#     print(data)
    neg = "select * from negative_words"
    cur.execute(neg)
    neg_words = cur.fetchall()
#     print(neg_words)
except Exception as e:
    print("ERROR=",e)
    
review = []
ip_addr = []
negatives = []

for i in review_data:
    review.append(i[2])
    ip_addr.append(i[1])

for i in neg_words:
    negatives.append(i[1])

me_list = ['i','me','myself']

ln = ['.com','.org','.net','.gov']

# print(ip_addr)
# print(negatives)
# Out:
# Database Connected

# %% [markdown]
# # VERIFICATION

# %%
def verify_fake(ip,r):
    v = [0 for i in range(5)]
    rev1 = r.split(" ")
    rev = [i.lower() for i in rev1]
    nc = 0
    myc = 0
    linkc = 0
    
    ipc = ip_addr.count(ip)
    for i in negatives:
        nc = nc + rev.count(i)
    myc = 0
    for i in me_list:
        myc = myc + rev.count(i)
    for i in rev:
        for j in ln:
            if j in i:
                linkc = linkc + 1
    if ipc > 1:
        v[0] = 1
    if nc > 3:
        v[1] = 1
    if myc > 5:
        v[2] = 1
    if linkc > 0:
        v[3] = 1
    if r in review:
        v[4] = 1
#     print(nc,myc,linkc,ipc)
#     print(v)
    return v

# %%
verify = ['Multiple reviews from same IP','Too many Negative Words','Self Promotion','Promotions via Links','Duplicate Review']

# %% [markdown]
# # IP GENERATION (FOR OFFLINE PURPOSES)

# %%
import random as r
def ip_generator():
    num = [i for i in range(255)]
    ip = str(r.choice(num))+"."+str(r.choice(num))+"."+str(r.choice(num))+"."+str(r.choice(num))
    return ip

# %% [markdown]
# # FAKE REVIEW DETECTION WITH ANALYSIS

# %%
import random as r
def review_detection(r_ip,ipr):
    result = ['','']
    fake_reasons = []
    
    if ipr == -1:
        return -1

    v = verify_fake(ipr,r_ip)
    if v.count(1)>=3:
        result[0] = 'FAKE'
    else:
        result[0] = 'NOT FAKE'
    for i in range(5):
        if v[i] == 1:
            fake_reasons.append(verify[i])
    
    preprocessedReview = reviewProcessor._processReview(r_ip)
    NB = NBayesClassifier.classify(extract_features(preprocessedReview))
    
    if NB == 'T':
        result[1] = 'POSITIVE'
    elif NB == 'F':
        result[1] = 'NEGATIVE'
    else:
        result[1] = 'UNDEFINED'
    
    result.append(fake_reasons)
    
    return result

# %%
import pickle
f = open('NBClassifier_1', 'rb')
model = pickle.load(f)
f.close()

# %% [markdown]
# # EXAMPLE

# %%
r_ip = input('Enter Review:-')
ip_ip = int(input('0 for repeat ip; 1 for new ip:-'))

if ip_ip == 0:
    ipr = r.choice(ip_addr)
elif ip_ip == 1:
    ipr = ip_generator()
else: 
    print("Invalid option")
    ipr = -1

# print(ipr)

answer = review_detection(r_ip,ipr)

if answer == -1:
    print("ERROR")
else:
    print()
    print()
    print("REVIEW CLASSIFICATION:")
    print(answer[1])
    print(answer[0])
    print()
    if answer[0] == 'FAKE':
        print("REASONS:")
        for i in answer[2]:
            print(i)
    if answer[0] == 'NOT FAKE':
        print("RAISED RED FLAGS:")
        for i in answer[2]:
            print(i)
#     print(answer)
# Out:
# Enter Review:-gfasdghasghdfsad
# 0 for repeat ip; 1 for new ip:-1
#
#
# REVIEW CLASSIFICATION:
# NEGATIVE
# NOT FAKE
#
# RAISED RED FLAGS:

# %%
# pathetic service, unhygenic and disgusting. We did not have a good time. never visit. Very Bad. visit xyz.com

# %% [markdown]
# # ADDITION OF NEW DATA TO DB

# %%
#Add review and IP to database
