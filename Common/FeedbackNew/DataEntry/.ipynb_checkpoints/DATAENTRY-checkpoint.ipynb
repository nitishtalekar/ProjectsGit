# %%
f = open(r"Teachers.txt")
x = f.readlines()
# print(x)
x.append("XX")
i = 1
fe = []
while x[i]!='COMPS\n':
    fe.append(x[i])
    i = i+1
i = i+1
c = []
while x[i]!='MECH\n':
    c.append(x[i])
    i = i+1
i = i+1
m = []
while x[i]!='EXTC\n':
    m.append(x[i])
    i = i+1
i = i+1
ex = []
while x[i]!='INSTRU\n':
    ex.append(x[i])
    i = i+1
i = i+1
ins = []
while x[i]!='IT\n':
    ins.append(x[i])
    i = i+1
i = i+1
it = []
while x[i]!='XX':
    it.append(x[i])
    i = i+1

fe = set(fe)
c = set(c)
m = set(m)
ex = set(ex)
ins = set(ins)
it = set(it)

ap = [("".join(list(i)[:-1]),'Applied Sciences') for i in fe]
com = [("".join(list(i)[:-1]),'Computer Engineering') for i in c]
mech = [("".join(list(i)[:-1]),'Mechanical Engineering') for i in m]
extc = [("".join(list(i)[:-1]),'Electronics and Telecommunication') for i in ex]
instr= [("".join(list(i)[:-1]),'Instumentation Engineering') for i in ins]
itech = [("".join(list(i)[:-1]),'Information Technology') for i in it]

final = ap+com+mech+extc+instr+itech

print(final)
# Out:
# [('Prof. Chhaya Hinge', 'Applied Sciences'), ('Dr. Y.S. Patil ', 'Applied Sciences'), ('Prof. N. S. Chame', 'Applied Sciences'), ('Prof.Shashikant Patil', 'Applied Sciences'), ('Prof. Shashank Gothankar', 'Applied Sciences'), ('Prof. Shalini Sharma', 'Applied Sciences'), ('Prof. Prasad Soman', 'Applied Sciences'), ('Prof. Rohini Ghule', 'Applied Sciences'), ('Prof. Chetan Rane', 'Applied Sciences'), ('Dr. Mala Chatterjee', 'Applied Sciences'), ('Prof. A.G.Ingole', 'Applied Sciences'), ('Prof. Rahul Chaurasiya', 'Applied Sciences'), ('Dr. Neeta Kapse ', 'Applied Sciences'), ('Prof. B. B. Sawant', 'Applied Sciences'), ('Dr. Pallavi Mahalle', 'Applied Sciences'), ('Prof. Nikhil V S', 'Applied Sciences'), ('Prof. Sanjana Repal', 'Applied Sciences'), ('Prof. R.N.Shanmukha', 'Applied Sciences'), ('Dr. S. K. Chaudhari', 'Applied Sciences'), ('Prof.Priyanka Deshmukh', 'Applied Sciences'), ('Prof.Suresh Mestry\t', 'Computer Engineering'), ('Prof. Priya Parate', 'Computer Engineering'), ('Prof.Naina Kaushik', 'Computer Engineering'), ('Prof. B.M. Patil', 'Computer Engineering'), ('Prof.A.Lahane', 'Computer Engineering'), ('Prof.Priyanka Bhilare', 'Computer Engineering'), ('Prof.Dnyaneshwar Kapse', 'Computer Engineering'), ('Prof. Kaajal Sharma', 'Computer Engineering'), ('Prof.Sharmila S. Gaikwad', 'Computer Engineering'), ('Prof.Dipak Gaikar', 'Computer Engineering'), ('Prof.Dyaneshwar Dhanagar', 'Computer Engineering'), ('Prof.Savita Lade', 'Computer Engineering'), ('Prof. Bhavesh Panchal', 'Computer Engineering'), ('Prof.Sumitra Sadhukhan', 'Computer Engineering'), ('Prof.D.S.Kale', 'Computer Engineering'), ('Prof.J.Deshmukh', 'Computer Engineering'), ('Prof.S.P.Khachane', 'Computer Engineering'), ('Prof. Dilip Dalgade', 'Computer Engineering'), ('Prof.Preeti Satao', 'Computer Engineering'), ('Prof. N. B. Shahapure', 'Mechanical Engineering'), ('Prof. M. R. Valse', 'Mechanical Engineering'), ('Dr. S. U. Bokade', 'Mechanical Engineering'), ('Prof N.J. Panaskar', 'Mechanical Engineering'), ('Prof. A. V. Gotmare', 'Mechanical Engineering'), ('Prof. A. V.Gotmare', 'Mechanical Engineering'), ('Prof. A.L.Mangrulkar', 'Mechanical Engineering'), ('Prof. R Gujar', 'Mechanical Engineering'), ('Prof. D. K. Chakradev', 'Mechanical Engineering'), ('Prof. R. R. Gujar', 'Mechanical Engineering'), ('Dr. R. V. Kale', 'Mechanical Engineering'), ('Prof. D.S. Pandey', 'Mechanical Engineering'), ('Prof. Nikhil.S', 'Mechanical Engineering'), ('Prof. N.J. Panaskar', 'Mechanical Engineering'), ('Prof. D. S. Pandey', 'Mechanical Engineering'), ('Prof. P. R. Paul', 'Mechanical Engineering'), ('Prof. C. R. Rane', 'Mechanical Engineering'), ('Prof. R. M. Siddiqui', 'Mechanical Engineering'), ('Prof. N. N. Bhostekar', 'Mechanical Engineering'), ('Prof. R. Y. Kurane', 'Mechanical Engineering'), ('Prof. R.Y. Kurane', 'Mechanical Engineering'), ('Prof. P. R. Potdar', 'Mechanical Engineering'), ('Prof. S. D. Gaikwad', 'Mechanical Engineering'), ('Dr. K. M. Chaudhari', 'Mechanical Engineering'), ('Prof. V. B. Sawant', 'Mechanical Engineering'), ('Prof. A. L. Mangrulkar', 'Mechanical Engineering'), ('Prof. N. K. Deshmukh', 'Mechanical Engineering'), ('Dr. A. G. Londhekar', 'Mechanical Engineering'), ('Prof. S. R. Sharma', 'Mechanical Engineering'), ('Prof.S.K.Gabhane', 'Electronics and Telecommunication'), ('Prof.P.A.Rokde', 'Electronics and Telecommunication'), ('Prof.S.S. Repal', 'Electronics and Telecommunication'), ('Prof.S.T.Sutar', 'Electronics and Telecommunication'), ('Prof.Rahul Chaurasiya', 'Electronics and Telecommunication'), ('Prof.M.U.Mokashi', 'Electronics and Telecommunication'), ('Prof.S.D.Patil', 'Electronics and Telecommunication'), ('Prof. S.D.Patil', 'Electronics and Telecommunication'), ('Prof.M.K.Ahirrao ', 'Electronics and Telecommunication'), ('Prof.P.N.Sonar', 'Electronics and Telecommunication'), ('Prof. P.N.Dave', 'Electronics and Telecommunication'), ('Prof.J.R.Mahajan', 'Electronics and Telecommunication'), ('Prof.A.R.Sagale', 'Electronic ...

# %%
import pymysql

db = pymysql.connect("localhost","root","","feedback_rgit" )

cursor = db.cursor()

sql = "INSERT INTO teacher (teacher_name, teacher_dept) VALUES (%s, %s)"
cursor.executemany(sql, final)

db.commit()

db.close()

# %%
f2 = open(r"Subjects-8.txt")
x = f2.readlines()
# print(x)
x.append("XX")
i = 1
fe = []
while x[i]!='COMPS\n':
    k = x[i].split(":")
    fe.append((k[0],k[1][:-1],'Applied Sciences'))
    i = i+1
i = i+1
c = []
while x[i]!='MECH\n':
    k = x[i].split(":")
    c.append((k[0],k[1][:-1],'Computer Engineering'))
    i = i+1
i = i+1
m = []
while x[i]!='EXTC\n':
    k = x[i].split(":")
    m.append((k[0],k[1][:-1],'Mechanical Engineering'))
    i=i+1
i = i+1
ex = []
while x[i]!='INSTRU\n':
    k = x[i].split(":")
    ex.append((k[0],k[1][:-1],'Electronics and Telecommunication'))
    i = i+1
i = i+1
ins = []
while x[i]!='IT\n':
    k = x[i].split(":")
    ins.append((k[0],k[1][:-1],'Instumentation Engineering'))
    i = i+1
i = i+1
its = []
while x[i]!='XX':
    k = x[i].split(":")
    its.append((k[0],k[1][:-1],'Information Technology'))
    i = i+1

final = fe+c+m+ex+ins+its

print(final)
# Out:
# [('Engineering Maths - 2', '2', 'Applied Sciences'), ('Engineering Physics - 2', '2', 'Applied Sciences'), ('Engineering Chemistry - 2', '2', 'Applied Sciences'), ('Engineering Graphics', '2', 'Applied Sciences'), ('C - Programming', '2', 'Applied Sciences'), ('PCE - 1', '2', 'Applied Sciences'), ('Applied Mathematics', '4', 'Computer Engineering'), ('Analysis Of Algorithm', '4', 'Computer Engineering'), ('Computer Organization & Architecture', '4', 'Computer Engineering'), ('Operating System', '4', 'Computer Engineering'), ('Computer graphics', '4', 'Computer Engineering'), ('Open Source Lab (Python)', '4', 'Computer Engineering'), ('System Programming and Compiler Construction', '6', 'Computer Engineering'), ('Software Engineering', '6', 'Computer Engineering'), ('Data Warehouse and Mining', '6', 'Computer Engineering'), ('Cryptography and System Security', '6', 'Computer Engineering'), ('Machine Learning', '6', 'Computer Engineering'), ('Natural Language Processing', '8', 'Computer Engineering'), ('Human Machine Interaction', '8', 'Computer Engineering'), ('Distributed Computing', '8', 'Computer Engineering'), ('CCL (Lab)', '8', 'Computer Engineering'), ('PM', '8', 'Computer Engineering'), ('DBM', '8', 'Computer Engineering'), ('RM', '8', 'Computer Engineering'), ('Kinematics of Machinery', '4', 'Mechanical Engineering'), ('Fluid Mechanics', '4', 'Mechanical Engineering'), ('Industrial Electronics', '4', 'Mechanical Engineering'), ('Database Information and Retrival', '4', 'Mechanical Engineering'), ('Product Planning - 2', '4', 'Mechanical Engineering'), ('Applied Mathematics', '4', 'Mechanical Engineering'), ('Refrigeration and Airconditioning', '6', 'Mechanical Engineering'), ('Machine Design - 1', '6', 'Mechanical Engineering'), ('Metrology and Quality Engineering', '6', 'Mechanical Engineering'), ('Finite Element Analysis', '6', 'Mechanical Engineering'), ('Industrial Automation', '6', 'Mechanical Engineering'), ('Mechatronics', '6', 'Mechanical Engineering'), ('Design pf Mechanical Systems', '8', 'Mechanical Engineering'), ('Power Engineering', '8', 'Mechanical Engineering'), ('Industrial Engineering and Management', '8', 'Mechanical Engineering'), ('Rapid Prototyping', '8', 'Mechanical Engineering'), ('Project Management', '8', 'Mechanical Engineering'), ('Research Management', '8', 'Mechanical Engineering'), ('Finance Management', '8', 'Mechanical Engineering'), ('Principles of Communication', '4', 'Electronics and Telecommunication'), ('Signals and Systems', '4', 'Electronics and Telecommunication'), ('Electronic Devices and Circuits-II', '4', 'Electronics and Telecommunication'), ('Linear Integrated Circuits', '4', 'Electronics and Telecommunication'), ('Applied Mathematics', '4', 'Electronics and Telecommunication'), ('IPVM', '6', 'Electronics and Telecommunication'), ('Antennas and Wave Propagation', '6', 'Electronics and Telecommunication'), ('Computer Communication Networks', '6', 'Electronics and Telecommunication'), ('Database Management System', '6', 'Electronics and Telecommunication'), ('DVLS I', '6', 'Electronics and Telecommunication'), ('Satellite Communication', '8', 'Electronics and Telecommunication'), ('Network Management in Telecommunication', '8', 'Electronics and Telecommunication'), ('Wireless Network', '8', 'Electronics and Telecommunication'), ('Finance Management', '8', 'Electronics and Telecommunication'), ('Enterprise Development Management', '8', 'Electronics and Telecommunication'), ('Research Metrology', '8', 'Electronics and Telecommunication'), ('R.F.D.', '8', 'Electronics and Telecommunication'), ('Transducer-II', '4', 'Instumentation Engineering'), ('Feedback Control System', '4', 'Instumentation Engineering'), ('Analytical Instrumentation', '4', 'Instumentation Engineering'), ('Signal Conditioning circuit Design', '4', 'Instumentation Engineering'), ('Application Software Practice', '4', 'Instumentation Engineering'), ('Applied Mathematics', '4', 'Instumentation Engineering'), ('Pr ...

# %%
import pymysql

db = pymysql.connect("localhost","root","","rgit_feedback" )

cursor = db.cursor()

sql = "INSERT INTO subject (sub_name,sub_sem,sub_dept ) VALUES (%s, %s, %s)"

cursor.executemany(sql, final)

db.commit()

db.close()

# %%
f2 = open(r"Subjects-7.txt")
x = f2.readlines()
# print(x)
x.append("XX")
i = 1
fe = []
while x[i]!='COMPS\n':
    k = x[i].split(":")
    fe.append((k[0],k[1][:-1],'Applied Sciences'))
    i = i+1
i = i+1
c = []
while x[i]!='MECH\n':
    k = x[i].split(":")
    c.append((k[0],k[1][:-1],'Computer Engineering'))
    i = i+1
i = i+1
m = []
while x[i]!='EXTC\n':
    k = x[i].split(":")
    m.append((k[0],k[1][:-1],'Mechanical Engineering'))
    i=i+1
i = i+1
ex = []
while x[i]!='INSTRU\n':
    k = x[i].split(":")
    ex.append((k[0],k[1][:-1],'Electronics and Telecommunication'))
    i = i+1
i = i+1
ins = []
while x[i]!='IT\n':
    k = x[i].split(":")
    ins.append((k[0],k[1][:-1],'Instumentation Engineering'))
    i = i+1
i = i+1
its = []
while x[i]!='XX':
    k = x[i].split(":")
    its.append((k[0],k[1][:-1],'Information Technology'))
    i = i+1

final = fe+c+m+ex+ins+its

print(final)

# %%
import pymysql
import random as r

li = ['1','2','3','4','5']

db = pymysql.connect("localhost","root","","feedback_rgit" )

cursor = db.cursor()

sql = "INSERT INTO feedback_temp(teacher_id, sub_id, ques1, ques2, ques3, ques4, ques5, ques6, ques7, ques8, ques9, ques10, ques11, ques12, remark) VALUES (%s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s)"

tid = ['4','20','16','17','2']
sid = ['1','2','3','4','5']
for j in range(5):
    feed = []
    for i in range(5):
        a = (tid[i],sid[i],r.choice(li),r.choice(li),r.choice(li),r.choice(li),r.choice(li),r.choice(li),r.choice(li),r.choice(li),r.choice(li),r.choice(li),r.choice(li),r.choice(li),r.choice(li))
        feed.append(a)
    cursor.executemany(sql, feed)
    db.commit()

db.close()

# %%
lazyass log,,, sab chiz python se karna hai

c me fft karo in nxn times
