# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tkinter 
from tkinter import *

# %% [markdown]
# # GUI

# %%
tk=tkinter.Tk()
tk.title("Big Data Analysis")
tk.geometry('500x300+80+80')

client = MongoClient()
db = client.ytdb
yt = db.ytdata
cursor = yt.find()
dat = [i for i in cursor]


def catg():
    c = yt.distinct('Category')
    cat = [i for i in c]
    cat_count = {}
    for i in cat:
        x = yt.find({'Category':i}).count()
        cat_count[i] = x
    catgraph = pd.DataFrame.from_dict(cat_count,orient='index')
    catgraph.plot.bar(figsize=(18,9),legend=False,title="Videos by Categories",rot=30)
    path = 'media/Category.jpg'
    plt.savefig(path)
    img = cv2.imread('media/Category.jpg')
    imS = cv2.resize(img, (1000, 500))
    cv2.imshow("Category",imS)
    
def ratg():
    rat = [1,2,3,4]
    rat_count = {}
    for i in rat:
        x = yt.find({'Rating':{"$gt":i, "$lt" :i+1}}).count()
        rat_count[(i,i+1)] = x
    ratgraph = pd.DataFrame.from_dict(rat_count,orient='index')
    ratgraph.plot.bar(figsize=(18,9),legend=False,title="Videos by Rating",rot=0,color='green')
    path = 'media/Rating.jpg'
    plt.savefig(path)
    img = cv2.imread('media/Rating.jpg')
    imS = cv2.resize(img, (1000, 500))
    cv2.imshow("Rating",imS)

def comg():
    com = [i for i in range(0,42,3)]
    com_count = {}
    for i in com:
        x = yt.find({'Comments':{"$gt":i, "$lt" :i+3}}).count()
        com_count[(i,i+3)] = x
    comgraph = pd.DataFrame.from_dict(com_count,orient='index')
    comgraph.plot.bar(figsize=(18,9),legend=False,title="Videos by Comment",rot=0,color='lightskyblue')
    path = 'media/Comments.jpg'
    plt.savefig(path)
    img = cv2.imread('media/Comments.jpg')
    imS = cv2.resize(img, (1000, 500))
    cv2.imshow("Comments",imS)
    
def lengg():
    leng = [i*100 for i in range(12)]
    leng_count = {}
    for i in leng:
        x = yt.find({'Length':{"$gt":i, "$lt" :i+100}}).count()
        leng_count[(i,i+100)] = x
    lenggraph = pd.DataFrame.from_dict(leng_count,orient='index')
    lenggraph.plot.bar(figsize=(18,9),legend=False,title="Videos by Length",rot=0,color='red')
    path = 'media/Length.jpg'
    plt.savefig(path)
    img = cv2.imread('media/Length.jpg')
    imS = cv2.resize(img, (1000, 500))
    cv2.imshow("Length",imS)

def top5():
    x = yt.find({},{'Uploader','Rating','Category','Views'},sort = [('Rating',pymongo.DESCENDING),('Views',pymongo.DESCENDING)])
    x1 = [i for i in x[0:5]]
    
    upl = [x1[i]['Uploader'] for i in range(5)]
    
    tk2=tkinter.Tk()
    tk2.title("Top 5 Youtubers")
    tk2.geometry('600x350+80+80')
    
    title2 = Label(tk2, text="TOP 5 Youtubers Data",font=5)
    title2.pack()
    
    upld = Label(tk2, text="YOUTUBER",font=4)
    upld.place(x =80,y=50)
    
    ratl = Label(tk2, text="AVG RATING",font=4)
    ratl.place(x =250,y=50)
    
    vil = Label(tk2, text="TOTAL VIEWS",font=4)
    vil.place(x =410,y=50)
    
    up_rat = {}
    up_view = {}
    lb_up = []
    lb_rat = []
    lb_vi = []
    lb_sr = []
    j = 0
    
    for i in upl:
        rat = pd.DataFrame(list(yt.find({'Uploader':i},{'Rating'})))
        rat.dropna(axis=0)
        up_rat[i] = [rat['Rating'].mean()]
        vi = pd.DataFrame(list(yt.find({'Uploader':i},{'Views'})))
        vi.dropna(axis=0)
        up_view[i] = [vi['Views'].sum()]
        lb_sr.append(Label(tk2, text=str(j+1)))
        lb_sr[j].place(x=70,y=100+(j*30))
        lb_up.append(Label(tk2, text=str(i)))
        lb_up[j].place(x=100,y=100+(j*30))
        lb_rat.append(Label(tk2, text=str(up_rat[i])))
        lb_rat[j].place(x=270,y=100+(j*30))
        lb_vi.append(Label(tk2, text=str(up_view[i])))
        lb_vi[j].place(x=440,y=100+(j*30))
        j=j+1
        
    def ratings():
        urat_graph = pd.DataFrame.from_dict(up_rat,orient='index')
        urat_graph.plot.barh(figsize=(15,10),legend=False,title='UPLOADER RATINGS',fontsize=13,color='salmon')
        path = 'media/Ratings.jpg'
        plt.savefig(path)
        img = cv2.imread('media/Ratings.jpg')
        imS = cv2.resize(img, (1000, 500))
        cv2.imshow("Rating",imS)
        
    def viewings():
        uvi_graph = pd.DataFrame.from_dict(up_view,orient='index')
        uvi_graph.plot.barh(figsize=(15,10),legend=False,title='UPLOADER VIEWINGS',fontsize=13,color='seagreen')
        path = 'media/Views.jpg'
        plt.savefig(path)
        img = cv2.imread('media/Views.jpg')
        imS = cv2.resize(img, (1000, 500))
        cv2.imshow("Views",imS)
        
    rtbtn = Button(tk2, text="Rating Comparison", command=ratings)
    rtbtn.place(x=125,y=300)
    vibtn = Button(tk2, text="Views Comparison", command=viewings)
    vibtn.place(x=325,y=300)
    tk2.mainloop()
    
def rank1():
    rk = int(rankval.get())
    x = yt.find({},{'Uploader'},sort = [('Rating',pymongo.DESCENDING),('Views',pymongo.DESCENDING)])
    x1 = [i for i in x[rk-1:rk]]
    rk_name = x1[0]['Uploader']
    urank.config(text=rk_name)

def profile():
    u_name = val.get()
    c = yt.distinct('Category')
    cat = [i for i in c]
    u_count = {}
    for i in cat:
        x = yt.find({'Uploader':u_name,'Category':i}).count()
        u_count[i] = x
    
    tk3=tkinter.Tk()
    tk3.title(str(u_name) + "'s Profile")
    tk3.geometry('250x350+80+80')
    
    urating = round(pd.DataFrame(list(yt.find({'Uploader':u_name},{'Rating'})))['Rating'].mean(),2)
    uview = round(pd.DataFrame(list(yt.find({'Uploader':u_name},{'Views'})))['Views'].sum(),2)
    
    def user_cat():
        u_graph = pd.DataFrame.from_dict(u_count,orient='index')
        u_graph.plot.pie(y=0,figsize=(12,12),fontsize=12,title='User Category Division')
        path = 'media/UCat.jpg'
        plt.savefig(path)
        img = cv2.imread('media/UCat.jpg')
        imS = cv2.resize(img, (500, 500))
        cv2.imshow("UCat",imS)
    
    utitle = Label(tk3, text=str(u_name) + "'s Profile",font=6)
    utitle.pack() 
    
    ub = Label(tk3, text="",font=2)
    ub.pack() 
    
    ur = Label(tk3, text="AVERAGE RATING",font=5)
    ur.pack() 
    ur2 = Label(tk3, text=str(urating),font=5)
    ur2.pack()
    
    ub2 = Label(tk3, text="",font=2)
    ub2.pack() 
    
    uv = Label(tk3, text="TOTAL VIEWS",font=5)
    uv.pack() 
    uv2 = Label(tk3, text=str(uview),font=5)
    uv2.pack() 
    
    ub3 = Label(tk3, text="",font=2)
    ub3.pack() 
    
    ucat = Button(tk3, text="Category Wise", command=user_cat)
    ucat.pack()
    
    tk3.mainloop()



title = Label(tk, text="YOUTUBE DATA ANALYSIS",font=5)
title.pack()

catbtn = Button(tk, text="By Category", command=catg)
catbtn.place(x=45,y=45)

ratbtn = Button(tk, text="By Rating", command=ratg)
ratbtn.place(x=155,y=45)

combtn = Button(tk, text="By Comments", command=comg)
combtn.place(x=255,y=45)

lengbtn = Button(tk, text="By Length", command=lengg)
lengbtn.place(x=375,y=45)

top5btn = Button(tk, text="TOP 5 Trending", command=top5)
top5btn.place(x=205,y=85)

user = Label(tk, text="ENTER USERNAME FOR ANALYSIS")
user.place(x=160,y=125)

val = StringVar()
text = Entry(tk,text=val)
text.place(x=190,y=155)

prbtn = Button(tk, text="PROFILE", command=profile)
prbtn.place(x=220,y=180)

rank = Label(tk, text="ENTER A RANK")
rank.place(x=40,y=230)

rankval = StringVar()
text1 = Entry(tk,text=rankval)
text1.place(x=150,y=230)

rbtn = Button(tk, text="SEARCH",command=rank1)
rbtn.place(x=290,y=230)

urank = Label(tk, text="")
urank.place(x=360,y=230)

tk.mainloop()

# %%
dat
# Out:
# [{'_id': ObjectId('5da2be3b1dc1408ebbe6f8aa'),
#   'ID': 'QuRYeRnAuXM',
#   'Uploader': 'EvilSquirrelPictures',
#   'Interval': 1135.0,
#   'Category': 'Pets & Animals',
#   'Length': 252.0,
#   'Views': 1075.0,
#   'Rating': 4.96,
#   'Num_Rating': 46.0,
#   'Comments': 86.0,
#   'RelativeID': 'gFa1YMEJFag'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ab'),
#   'ID': '3TYqkBJ9YRk',
#   'Uploader': 'hggh22',
#   'Interval': 1135.0,
#   'Category': 'Comedy',
#   'Length': 169.0,
#   'Views': 228.0,
#   'Rating': 5.0,
#   'Num_Rating': 5.0,
#   'Comments': 3.0,
#   'RelativeID': 'QuRYeRnAuXM'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ac'),
#   'ID': 'rSJ8QZWBegU',
#   'Uploader': 'TimeGem',
#   'Interval': 1135.0,
#   'Category': 'Entertainment',
#   'Length': 95.0,
#   'Views': 356.0,
#   'Rating': 4.31,
#   'Num_Rating': 13.0,
#   'Comments': 1.0,
#   'RelativeID': 'QuRYeRnAuXM'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ad'),
#   'ID': 'nRcovJn9xHg',
#   'Uploader': 'wooochacha',
#   'Interval': 1135.0,
#   'Category': 'Entertainment',
#   'Length': 118.0,
#   'Views': 1115.0,
#   'Rating': 2.23,
#   'Num_Rating': 57.0,
#   'Comments': 73.0,
#   'RelativeID': 'QuRYeRnAuXM'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ae'),
#   'ID': 'UEvVksP91kg',
#   'Uploader': 'johnx113',
#   'Interval': 1135.0,
#   'Category': 'Entertainment',
#   'Length': 83.0,
#   'Views': 281.0,
#   'Rating': 2.67,
#   'Num_Rating': 9.0,
#   'Comments': 16.0,
#   'RelativeID': 'gFa1YMEJFag'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8af'),
#   'ID': 'sVkuOk4jmCo',
#   'Uploader': 'marcosoycadiz',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 49.0,
#   'Views': 1196.0,
#   'Rating': 3.67,
#   'Num_Rating': 6.0,
#   'Comments': 5.0,
#   'RelativeID': 'yjt5v88-6Aw'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b0'),
#   'ID': 'ZTopArY7Nbg',
#   'Uploader': 'TroyChannel',
#   'Interval': 1136.0,
#   'Category': 'Entertainment',
#   'Length': 145.0,
#   'Views': 11.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 0.0,
#   'RelativeID': 'THM3FYUNyr8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b1'),
#   'ID': '0RViGi2Rne8',
#   'Uploader': 'OmnipotentSI',
#   'Interval': 1135.0,
#   'Category': 'Entertainment',
#   'Length': 9.0,
#   'Views': 490.0,
#   'Rating': 2.31,
#   'Num_Rating': 26.0,
#   'Comments': 15.0,
#   'RelativeID': 'rSJ8QZWBegU'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b2'),
#   'ID': 'HT_QlOJbDpg',
#   'Uploader': 'dumbasstheredneck',
#   'Interval': 1095.0,
#   'Category': 'Comedy',
#   'Length': 14.0,
#   'Views': 1349.0,
#   'Rating': 2.09,
#   'Num_Rating': 22.0,
#   'Comments': 13.0,
#   'RelativeID': 'cdbp6rCVzRs'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b3'),
#   'ID': 'ShhClb6J-NA',
#   'Uploader': 'thecrashguy',
#   'Interval': 1136.0,
#   'Category': 'Entertainment',
#   'Length': 61.0,
#   'Views': 29.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 0.0,
#   'RelativeID': '8dEezTw8J_o'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b4'),
#   'ID': 'g9e1alirMhc',
#   'Uploader': 'iamdanielisaac',
#   'Interval': 541.0,
#   'Category': 'Comedy',
#   'Length': 152.0,
#   'Views': 483053.0,
#   'Rating': 4.65,
#   'Num_Rating': 2689.0,
#   'Comments': 2932.0,
#   'RelativeID': '_i6OD_y_-AI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b5'),
#   'ID': 'YZev1imoxX8',
#   'Uploader': 'threefirstnames',
#   'Interval': 1135.0,
#   'Category': 'Entertainment',
#   'Length': 253.0,
#   'Views': 63.0,
#   'Rating': 5.0,
#   'Num_Rating': 3.0,
#   'Comments': 2.0,
#   'RelativeID': 'ldZPDf2cwqI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b6'),
#   'ID': 'I4yKEK9o8gA',
#   'Uploader': 'djlogitek',
#   'Interval': 964.0,
#   'Category': 'News & Politics',
#   'Length': 173.0,
#   'Views': 106929.0,
#   'Rating': 4.39,
#   'Num_Rating': 1010.0,
#   'Comments': 1484.0,
#   'RelativeID': 'g9e1alirMhc'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b7'),
#   'ID': '1GKaVzNDbuI',
#   'Uploader': 'fatvids',
#   'Interval': 690.0,
#   'Category': 'Comedy',
#   'Length': 176.0,
#   'Views': 2464486.0,
#   'Rating': 4.5,
#   'Num_Rating': 13342.0,
#   'Comments': 11997.0,
#   'RelativeID': 'Bd61LnxqSng'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b8'),
#   'ID': 'yuZhwV24PmM',
#   'Uploader': 'weneedhelp',
#   'Interval': 1082.0,
#   'Category': 'News & Politics',
#   'Length': 213.0,
#   'Views': 46183.0,
#   'Rating': 4.71,
#   'Num_Rating': 280.0,
#   'Comments': 247.0,
#   'RelativeID': 'hU9iCANi02o'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8b9'),
#   'ID': 'zQ83d_D2MGs',
#   'Uploader': 'dumbasstheredneck',
#   'Interval': 1095.0,
#   'Category': 'Comedy',
#   'Length': 14.0,
#   'Views': 1550.0,
#   'Rating': 1.57,
#   'Num_Rating': 14.0,
#   'Comments': 4.0,
#   'RelativeID': 'HT_QlOJbDpg'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ba'),
#   'ID': 'DomumdGQSg8',
#   'Uploader': 'imgrown18',
#   'Interval': 910.0,
#   'Category': 'Comedy',
#   'Length': 224.0,
#   'Views': 392908.0,
#   'Rating': 4.8,
#   'Num_Rating': 1261.0,
#   'Comments': 829.0,
#   'RelativeID': 'lVTS0iuo1EY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8bb'),
#   'ID': 'pFUYi7dp1WU',
#   'Uploader': 'StanleyJenkins',
#   'Interval': 1106.0,
#   'Category': 'Comedy',
#   'Length': 200.0,
#   'Views': 110272.0,
#   'Rating': 4.07,
#   'Num_Rating': 1011.0,
#   'Comments': 482.0,
#   'RelativeID': '_1haYY5pV18'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8bc'),
#   'ID': '2l6vwAIAqNU',
#   'Uploader': 'makemagazine',
#   'Interval': 460.0,
#   'Category': 'Film & Animation',
#   'Length': 294.0,
#   'Views': 71966.0,
#   'Rating': 4.07,
#   'Num_Rating': 260.0,
#   'Comments': 229.0,
#   'RelativeID': 'g9e1alirMhc'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8bd'),
#   'ID': 'hiSmlmXp-aU',
#   'Uploader': 'bravenewfilms',
#   'Interval': 440.0,
#   'Category': 'Entertainment',
#   'Length': 168.0,
#   'Views': 653840.0,
#   'Rating': 4.43,
#   'Num_Rating': 198.0,
#   'Comments': 377.0,
#   'RelativeID': 'ED6YaRl93CE'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8be'),
#   'ID': 'dh6dF1XY3uI',
#   'Uploader': 'Ffllaanndd',
#   'Interval': 1090.0,
#   'Category': 'Entertainment',
#   'Length': 249.0,
#   'Views': 146.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 1.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8bf'),
#   'ID': '_a0gQFOJYWM',
#   'Uploader': 'diamondfan1910',
#   'Interval': 1011.0,
#   'Category': 'Film & Animation',
#   'Length': 369.0,
#   'Views': 728.0,
#   'Rating': 4.64,
#   'Num_Rating': 11.0,
#   'Comments': 17.0,
#   'RelativeID': 'dN0NcMm9qZo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c0'),
#   'ID': 'UzPldH0vuHY',
#   'Uploader': 'Ffllaanndd',
#   'Interval': 1100.0,
#   'Category': 'Entertainment',
#   'Length': 424.0,
#   'Views': 229.0,
#   'Rating': 4.0,
#   'Num_Rating': 4.0,
#   'Comments': 2.0,
#   'RelativeID': 'Gfv3UpKGkl8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c1'),
#   'ID': 'h9gRdAmGFnM',
#   'Uploader': 'LinIsKorean',
#   'Interval': 1067.0,
#   'Category': 'Entertainment',
#   'Length': 410.0,
#   'Views': 220.0,
#   'Rating': 4.33,
#   'Num_Rating': 6.0,
#   'Comments': 9.0,
#   'RelativeID': 'wZuzB4i4HLA'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c2'),
#   'ID': 'rKWq0l6YiT0',
#   'Uploader': 'ratfink43',
#   'Interval': 719.0,
#   'Category': 'News & Politics',
#   'Length': 37.0,
#   'Views': 4446.0,
#   'Rating': 4.81,
#   'Num_Rating': 21.0,
#   'Comments': 8.0,
#   'RelativeID': 'XeolH-kzx4c'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c3'),
#   'ID': 'M67aD5lLC2M',
#   'Uploader': 'zeldamastertimmy2',
#   'Interval': 1100.0,
#   'Category': 'Entertainment',
#   'Length': 477.0,
#   'Views': 379.0,
#   'Rating': 4.2,
#   'Num_Rating': 10.0,
#   'Comments': 5.0,
#   'RelativeID': '0oLMy5wWn30'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c4'),
#   'ID': 'gP0jnBrVEpI',
#   'Uploader': 'NoodleStroodel',
#   'Interval': 1069.0,
#   'Category': 'Film & Animation',
#   'Length': 107.0,
#   'Views': 161.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 2.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c5'),
#   'ID': 'geUY_esOrt0',
#   'Uploader': 'samsarajade',
#   'Interval': 1108.0,
#   'Category': 'Comedy',
#   'Length': 218.0,
#   'Views': 664.0,
#   'Rating': 5.0,
#   'Num_Rating': 12.0,
#   'Comments': 27.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c6'),
#   'ID': 'kIxj9S6jiB4',
#   'Uploader': 'GoldGlove01',
#   'Interval': 1089.0,
#   'Category': 'Film & Animation',
#   'Length': 79.0,
#   'Views': 25.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 0.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c7'),
#   'ID': 'mfUwgrwkqiI',
#   'Uploader': 'Dukescubbie',
#   'Interval': 881.0,
#   'Category': 'People & Blogs',
#   'Length': 53.0,
#   'Views': 447.0,
#   'Rating': 4.86,
#   'Num_Rating': 7.0,
#   'Comments': 2.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c8'),
#   'ID': '0jjrvtqa-BQ',
#   'Uploader': 'easterfilms',
#   'Interval': 800.0,
#   'Category': 'Entertainment',
#   'Length': 137.0,
#   'Views': 523.0,
#   'Rating': 4.2,
#   'Num_Rating': 10.0,
#   'Comments': 9.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8c9'),
#   'ID': 'VoPgxHja4Os',
#   'Uploader': 'Djclyve',
#   'Interval': 744.0,
#   'Category': 'Entertainment',
#   'Length': 340.0,
#   'Views': 1083.0,
#   'Rating': 2.33,
#   'Num_Rating': 3.0,
#   'Comments': 0.0,
#   'RelativeID': 'a1Gqpdrna9Y'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ca'),
#   'ID': 'QJMZjx4L0BA',
#   'Uploader': 'diamondfan1910',
#   'Interval': 1038.0,
#   'Category': 'Film & Animation',
#   'Length': 322.0,
#   'Views': 230.0,
#   'Rating': 5.0,
#   'Num_Rating': 4.0,
#   'Comments': 9.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8cb'),
#   'ID': 'OshpuI9BGVU',
#   'Uploader': 'mywiiowns',
#   'Interval': 883.0,
#   'Category': 'Entertainment',
#   'Length': 608.0,
#   'Views': 406.0,
#   'Rating': 2.43,
#   'Num_Rating': 7.0,
#   'Comments': 4.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8cc'),
#   'ID': 'eBGIQ7ZuuiU',
#   'Uploader': 'YouGotRickRolled',
#   'Interval': 832.0,
#   'Category': 'Comedy',
#   'Length': 210.0,
#   'Views': 8119804.0,
#   'Rating': 4.64,
#   'Num_Rating': 23256.0,
#   'Comments': 29160.0,
#   'RelativeID': 'oHg5SJYRHA0'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8cd'),
#   'ID': 'L3mR8syHNIg',
#   'Uploader': 'DarkArchon102',
#   'Interval': 1068.0,
#   'Category': 'Entertainment',
#   'Length': 84.0,
#   'Views': 109.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 7.0,
#   'RelativeID': 'WW4Lvnr07Hw'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ce'),
#   'ID': 'McZ3lP8lb6E',
#   'Uploader': 'uglydollfreak',
#   'Interval': 1089.0,
#   'Category': 'Entertainment',
#   'Length': 614.0,
#   'Views': 146.0,
#   'Rating': 2.5,
#   'Num_Rating': 2.0,
#   'Comments': 5.0,
#   'RelativeID': 'LDU9qX_Y1Xo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8cf'),
#   'ID': 'WsaQ0dQhXnA',
#   'Uploader': 'SamProof',
#   'Interval': 861.0,
#   'Category': 'Entertainment',
#   'Length': 226.0,
#   'Views': 3685.0,
#   'Rating': 4.85,
#   'Num_Rating': 33.0,
#   'Comments': 80.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d0'),
#   'ID': '16XHS2R_mEo',
#   'Uploader': 'Zarzycki3000',
#   'Interval': 1060.0,
#   'Category': 'Entertainment',
#   'Length': 212.0,
#   'Views': 57.0,
#   'Rating': 2.33,
#   'Num_Rating': 3.0,
#   'Comments': 2.0,
#   'RelativeID': 'L3mR8syHNIg'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d1'),
#   'ID': 'lhGZVgoDub0',
#   'Uploader': 'WhiteKhakis',
#   'Interval': 965.0,
#   'Category': 'Entertainment',
#   'Length': 291.0,
#   'Views': 5481.0,
#   'Rating': 4.64,
#   'Num_Rating': 14.0,
#   'Comments': 18.0,
#   'RelativeID': 'Bgzgj25CmKg'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d2'),
#   'ID': 'aYHBqH_xbCw',
#   'Uploader': 'Ryokibin',
#   'Interval': 1133.0,
#   'Category': 'News & Politics',
#   'Length': 521.0,
#   'Views': 11327.0,
#   'Rating': 4.77,
#   'Num_Rating': 96.0,
#   'Comments': 190.0,
#   'RelativeID': 'EZT0_Kmyfl0'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d3'),
#   'ID': 'SfaxA9Q-9AQ',
#   'Uploader': 'CBS',
#   'Interval': 1134.0,
#   'Category': 'News & Politics',
#   'Length': 177.0,
#   'Views': 25618.0,
#   'Rating': 4.86,
#   'Num_Rating': 182.0,
#   'Comments': 153.0,
#   'RelativeID': 'Pef5AUt-tic'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d4'),
#   'ID': '1cWWE3A2mDI',
#   'Uploader': 'davoodnpussy',
#   'Interval': 1135.0,
#   'Category': 'News & Politics',
#   'Length': 89.0,
#   'Views': 3947.0,
#   'Rating': 1.46,
#   'Num_Rating': 69.0,
#   'Comments': 49.0,
#   'RelativeID': 'gtyYEwQwc28'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d5'),
#   'ID': 'exT_E9FNu84',
#   'Uploader': 'zabbabou',
#   'Interval': 1136.0,
#   'Category': 'News & Politics',
#   'Length': 63.0,
#   'Views': 549.0,
#   'Rating': 3.15,
#   'Num_Rating': 13.0,
#   'Comments': 11.0,
#   'RelativeID': 'gtyYEwQwc28'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d6'),
#   'ID': 'osqnkdc349s',
#   'Uploader': 'giantPANDER',
#   'Interval': 1135.0,
#   'Category': 'News & Politics',
#   'Length': 132.0,
#   'Views': 597.0,
#   'Rating': 5.0,
#   'Num_Rating': 4.0,
#   'Comments': 1.0,
#   'RelativeID': 'SfaxA9Q-9AQ'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d7'),
#   'ID': '5lWlN8g2dAc',
#   'Uploader': 'JoannaLloyduynsv',
#   'Interval': 1134.0,
#   'Category': 'News & Politics',
#   'Length': 53.0,
#   'Views': 2511.0,
#   'Rating': 4.43,
#   'Num_Rating': 7.0,
#   'Comments': 9.0,
#   'RelativeID': '6KqmfUFZbBw'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d8'),
#   'ID': 'ZCYtPT_bpTI',
#   'Uploader': 'speakmymind01',
#   'Interval': 1133.0,
#   'Category': 'News & Politics',
#   'Length': 116.0,
#   'Views': 5321.0,
#   'Rating': 4.77,
#   'Num_Rating': 30.0,
#   'Comments': 60.0,
#   'RelativeID': '8BfNqhV5hg4'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8d9'),
#   'ID': '6KqmfUFZbBw',
#   'Uploader': 'ScrappleFace',
#   'Interval': 1134.0,
#   'Category': 'News & Politics',
#   'Length': 45.0,
#   'Views': 12971.0,
#   'Rating': 4.57,
#   'Num_Rating': 23.0,
#   'Comments': 44.0,
#   'RelativeID': '5lWlN8g2dAc'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8da'),
#   'ID': 'Y_hAXbgxXp8',
#   'Uploader': 'andiKentvmai',
#   'Interval': 1135.0,
#   'Category': 'News & Politics',
#   'Length': 124.0,
#   'Views': 209.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 8.0,
#   'RelativeID': 'ZCYtPT_bpTI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8db'),
#   'ID': 'IxVsdS887HA',
#   'Uploader': 'wazolangu',
#   'Interval': 1130.0,
#   'Category': 'News & Politics',
#   'Length': 39.0,
#   'Views': 44203.0,
#   'Rating': 4.72,
#   'Num_Rating': 184.0,
#   'Comments': 208.0,
#   'RelativeID': 'D01Wa2PLquU'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8dc'),
#   'ID': 'L1WYOl2_5Kg',
#   'Uploader': 'iaxiloll',
#   'Interval': 1134.0,
#   'Category': 'News & Politics',
#   'Length': 382.0,
#   'Views': 4648.0,
#   'Rating': 4.48,
#   'Num_Rating': 31.0,
#   'Comments': 119.0,
#   'RelativeID': 'iOsGo_HWP-c'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8dd'),
#   'ID': 'bjAuzPnJ82A',
#   'Uploader': 'lotarvk',
#   'Interval': 1134.0,
#   'Category': 'News & Politics',
#   'Length': 122.0,
#   'Views': 6715.0,
#   'Rating': 4.82,
#   'Num_Rating': 33.0,
#   'Comments': 166.0,
#   'RelativeID': '8BfNqhV5hg4'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8de'),
#   'ID': 'E8_odhuWfTk',
#   'Uploader': 'SteveMarmel',
#   'Interval': 1131.0,
#   'Category': 'Comedy',
#   'Length': 149.0,
#   'Views': 53950.0,
#   'Rating': 4.68,
#   'Num_Rating': 341.0,
#   'Comments': 572.0,
#   'RelativeID': 'rc01OYUYLes'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8df'),
#   'ID': 'TKe2rBbGGEA',
#   'Uploader': 'go33tv',
#   'Interval': 1134.0,
#   'Category': 'News & Politics',
#   'Length': 138.0,
#   'Views': 10240.0,
#   'Rating': 4.77,
#   'Num_Rating': 44.0,
#   'Comments': 118.0,
#   'RelativeID': '4sb1XXb_9sM'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e0'),
#   'ID': 'lwrxclIGJqk',
#   'Uploader': 'oonkamoonka',
#   'Interval': 1134.0,
#   'Category': 'Comedy',
#   'Length': 71.0,
#   'Views': 11888.0,
#   'Rating': 4.48,
#   'Num_Rating': 58.0,
#   'Comments': 77.0,
#   'RelativeID': 'qR28n3L4f9A'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e1'),
#   'ID': 'T3depGF5E-0',
#   'Uploader': 'llamomanu',
#   'Interval': 1133.0,
#   'Category': 'News & Politics',
#   'Length': 219.0,
#   'Views': 51837.0,
#   'Rating': 4.71,
#   'Num_Rating': 390.0,
#   'Comments': 795.0,
#   'RelativeID': 'eb-FIdshnVg'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e2'),
#   'ID': '9l2qbaOMbcU',
#   'Uploader': 'ciwanamed',
#   'Interval': 1135.0,
#   'Category': 'News & Politics',
#   'Length': 116.0,
#   'Views': 894.0,
#   'Rating': 5.0,
#   'Num_Rating': 3.0,
#   'Comments': 6.0,
#   'RelativeID': 'iOsGo_HWP-c'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e3'),
#   'ID': '2hZx3yBoNw4',
#   'Uploader': 'CBSEXPosed',
#   'Interval': 1134.0,
#   'Category': 'News & Politics',
#   'Length': 116.0,
#   'Views': 7515.0,
#   'Rating': 5.0,
#   'Num_Rating': 2.0,
#   'Comments': 0.0,
#   'RelativeID': '8BfNqhV5hg4'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e4'),
#   'ID': 'UCeA4K2-wNk',
#   'Uploader': 'spityogamecom',
#   'Interval': 856.0,
#   'Category': 'Music',
#   'Length': 294.0,
#   'Views': 390697.0,
#   'Rating': 3.77,
#   'Num_Rating': 1320.0,
#   'Comments': 2351.0,
#   'RelativeID': 'zwxljUHq1n4'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e5'),
#   'ID': 'BDmhe0vIFiQ',
#   'Uploader': 'SpTgUrL2010',
#   'Interval': 1063.0,
#   'Category': 'Music',
#   'Length': 166.0,
#   'Views': 3768.0,
#   'Rating': 3.75,
#   'Num_Rating': 16.0,
#   'Comments': 15.0,
#   'RelativeID': 'UCeA4K2-wNk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e6'),
#   'ID': '9xSvVPa41Cg',
#   'Uploader': nan,
#   'Interval': nan,
#   'Category': nan,
#   'Length': nan,
#   'Views': nan,
#   'Rating': nan,
#   'Num_Rating': nan,
#   'Comments': nan,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e7'),
#   'ID': '3Cc7-4OeAgM',
#   'Uploader': 'joris6440',
#   'Interval': 1127.0,
#   'Category': 'Music',
#   'Length': 303.0,
#   'Views': 368.0,
#   'Rating': 4.6,
#   'Num_Rating': 10.0,
#   'Comments': 4.0,
#   'RelativeID': '7h8abJUidwA'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e8'),
#   'ID': 'NDtHpG0c0Cc',
#   'Uploader': 'reidooproductions',
#   'Interval': 1135.0,
#   'Category': 'Howto & Style',
#   'Length': 185.0,
#   'Views': 84.0,
#   'Rating': 2.67,
#   'Num_Rating': 3.0,
#   'Comments': 2.0,
#   'RelativeID': 'UCeA4K2-wNk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8e9'),
#   'ID': 'e5L0hW2Dj10',
#   'Uploader': 'MYHOODURHOOD2',
#   'Interval': 1135.0,
#   'Category': 'Music',
#   'Length': 64.0,
#   'Views': 199.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 1.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ea'),
#   'ID': 'UmAa8JTm1Cc',
#   'Uploader': 'iRespond2U',
#   'Interval': 1135.0,
#   'Category': 'Music',
#   'Length': 59.0,
#   'Views': 116.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 7.0,
#   'RelativeID': 'UCeA4K2-wNk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8eb'),
#   'ID': '-zDIXUSL174',
#   'Uploader': 'headz22',
#   'Interval': 1136.0,
#   'Category': 'Music',
#   'Length': 104.0,
#   'Views': 48.0,
#   'Rating': 5.0,
#   'Num_Rating': 2.0,
#   'Comments': 1.0,
#   'RelativeID': 'UCeA4K2-wNk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ec'),
#   'ID': 'QXEdjYf5ezY',
#   'Uploader': 'spityogamecom',
#   'Interval': 858.0,
#   'Category': 'Music',
#   'Length': 401.0,
#   'Views': 267189.0,
#   'Rating': 4.69,
#   'Num_Rating': 442.0,
#   'Comments': 407.0,
#   'RelativeID': 'G84LhBePK6k'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ed'),
#   'ID': 'G84LhBePK6k',
#   'Uploader': 'spityogamecom',
#   'Interval': 864.0,
#   'Category': 'Music',
#   'Length': 356.0,
#   'Views': 200754.0,
#   'Rating': 4.76,
#   'Num_Rating': 364.0,
#   'Comments': 264.0,
#   'RelativeID': 'QXEdjYf5ezY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ee'),
#   'ID': 'OnosHPTij3M',
#   'Uploader': 'mi3456789',
#   'Interval': 1112.0,
#   'Category': 'Entertainment',
#   'Length': 295.0,
#   'Views': 247.0,
#   'Rating': 4.0,
#   'Num_Rating': 5.0,
#   'Comments': 1.0,
#   'RelativeID': 'Dms9iAI80w8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ef'),
#   'ID': 'yhGd25KcOh4',
#   'Uploader': 'spityogamecom',
#   'Interval': 852.0,
#   'Category': 'Music',
#   'Length': 187.0,
#   'Views': 164387.0,
#   'Rating': 4.82,
#   'Num_Rating': 108.0,
#   'Comments': 47.0,
#   'RelativeID': 'G84LhBePK6k'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f0'),
#   'ID': 'Cj_S_rut3LQ',
#   'Uploader': 'MrCeoBoy',
#   'Interval': 989.0,
#   'Category': 'Music',
#   'Length': 176.0,
#   'Views': 762.0,
#   'Rating': 5.0,
#   'Num_Rating': 4.0,
#   'Comments': 7.0,
#   'RelativeID': '2iUzQqtrmRU'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f1'),
#   'ID': 'XNyINFMHHm4',
#   'Uploader': 'MRMAKEEMBOP',
#   'Interval': 1118.0,
#   'Category': 'Music',
#   'Length': 152.0,
#   'Views': 665.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 1.0,
#   'RelativeID': 'eA0wwOXG45I'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f2'),
#   'ID': '6hIis-_GIXk',
#   'Uploader': 'jessy0525',
#   'Interval': 859.0,
#   'Category': 'People & Blogs',
#   'Length': 240.0,
#   'Views': 1195.0,
#   'Rating': 3.67,
#   'Num_Rating': 3.0,
#   'Comments': 6.0,
#   'RelativeID': '2ShxpwuZygI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f3'),
#   'ID': 'hd6yq-HIibI',
#   'Uploader': 'Chevymalibu12',
#   'Interval': 835.0,
#   'Category': 'Music',
#   'Length': 202.0,
#   'Views': 330284.0,
#   'Rating': 4.72,
#   'Num_Rating': 392.0,
#   'Comments': 259.0,
#   'RelativeID': 'S2GXb8li5Xo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f4'),
#   'ID': 'ZEDYzwdqHrU',
#   'Uploader': 'MRMAKEEMBOP',
#   'Interval': 1117.0,
#   'Category': 'Music',
#   'Length': 111.0,
#   'Views': 158.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 0.0,
#   'RelativeID': 'S7xjDoq9040'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f5'),
#   'ID': 't02kRsw1AUU',
#   'Uploader': 'bihwiLoganqjrg',
#   'Interval': 1135.0,
#   'Category': 'Music',
#   'Length': 193.0,
#   'Views': 236.0,
#   'Rating': 4.2,
#   'Num_Rating': 5.0,
#   'Comments': 5.0,
#   'RelativeID': 'UCeA4K2-wNk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f6'),
#   'ID': 'H4kZqk1NF4U',
#   'Uploader': 'symonds4260',
#   'Interval': 1079.0,
#   'Category': 'Music',
#   'Length': 294.0,
#   'Views': 419.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 0.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f7'),
#   'ID': 'J52gclijmWw',
#   'Uploader': 'spityogamecom',
#   'Interval': 854.0,
#   'Category': 'Music',
#   'Length': 187.0,
#   'Views': 44965.0,
#   'Rating': 4.82,
#   'Num_Rating': 98.0,
#   'Comments': 65.0,
#   'RelativeID': '_lQxqblSnoY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f8'),
#   'ID': '5vLbA7n8EG0',
#   'Uploader': 'alexasWelchvpjjc',
#   'Interval': 1135.0,
#   'Category': 'News & Politics',
#   'Length': 53.0,
#   'Views': 1003.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 7.0,
#   'RelativeID': 'DCAO6bZa31o'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8f9'),
#   'ID': '3ZbXJp-NUZc',
#   'Uploader': 'puebloplug',
#   'Interval': 1135.0,
#   'Category': 'News & Politics',
#   'Length': 13.0,
#   'Views': 784.0,
#   'Rating': 2.47,
#   'Num_Rating': 19.0,
#   'Comments': 5.0,
#   'RelativeID': 'DCAO6bZa31o'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8fa'),
#   'ID': 'McYsnvAymV8',
#   'Uploader': nan,
#   'Interval': nan,
#   'Category': nan,
#   'Length': nan,
#   'Views': nan,
#   'Rating': nan,
#   'Num_Rating': nan,
#   'Comments': nan,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8fb'),
#   'ID': 'MaE1kowuCBQ',
#   'Uploader': 'tottigol1020',
#   'Interval': 390.0,
#   'Category': 'Sports',
#   'Length': 117.0,
#   'Views': 742374.0,
#   'Rating': 4.46,
#   'Num_Rating': 597.0,
#   'Comments': 503.0,
#   'RelativeID': '3ds7V085k7g'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8fc'),
#   'ID': 'N1RMCuIUB9c',
#   'Uploader': 'NettwerkMusic',
#   'Interval': 563.0,
#   'Category': 'Music',
#   'Length': 190.0,
#   'Views': 288213.0,
#   'Rating': 4.84,
#   'Num_Rating': 1051.0,
#   'Comments': 654.0,
#   'RelativeID': '6WqDWJdBTx8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8fd'),
#   'ID': 'FZK4BRN6D9w',
#   'Uploader': 'AREQCFC',
#   'Interval': 851.0,
#   'Category': 'People & Blogs',
#   'Length': 365.0,
#   'Views': 117139.0,
#   'Rating': 4.8,
#   'Num_Rating': 272.0,
#   'Comments': 211.0,
#   'RelativeID': '6nAe6ke2M0Q'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8fe'),
#   'ID': 'pM3GHI5xR9U',
#   'Uploader': 'savas82',
#   'Interval': 458.0,
#   'Category': 'Sports',
#   'Length': 194.0,
#   'Views': 732199.0,
#   'Rating': 4.69,
#   'Num_Rating': 1457.0,
#   'Comments': 434.0,
#   'RelativeID': 'zv47ay3aJbs'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f8ff'),
#   'ID': '3ds7V085k7g',
#   'Uploader': 'tottigol1020',
#   'Interval': 390.0,
#   'Category': 'Sports',
#   'Length': 182.0,
#   'Views': 702596.0,
#   'Rating': 4.5,
#   'Num_Rating': 617.0,
#   'Comments': 655.0,
#   'RelativeID': 'MaE1kowuCBQ'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f900'),
#   'ID': 'clhOnZRrmXc',
#   'Uploader': 'ped666',
#   'Interval': 527.0,
#   'Category': 'Music',
#   'Length': 230.0,
#   'Views': 2135635.0,
#   'Rating': 4.8,
#   'Num_Rating': 3747.0,
#   'Comments': 1856.0,
#   'RelativeID': 'pKQK8rYZNHY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f901'),
#   'ID': 'TPUZqcibh4E',
#   'Uploader': 'daRangers',
#   'Interval': 613.0,
#   'Category': 'Music',
#   'Length': 225.0,
#   'Views': 1102105.0,
#   'Rating': 4.82,
#   'Num_Rating': 2608.0,
#   'Comments': 1324.0,
#   'RelativeID': 'pKQK8rYZNHY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f902'),
#   'ID': 'OIxgw04Y0Fc',
#   'Uploader': 'Veracifier',
#   'Interval': 1088.0,
#   'Category': 'News & Politics',
#   'Length': 113.0,
#   'Views': 96500.0,
#   'Rating': 4.34,
#   'Num_Rating': 216.0,
#   'Comments': 823.0,
#   'RelativeID': 'ClM3sC_EzN4'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f903'),
#   'ID': '13YOGHzzoMA',
#   'Uploader': '360Gamerz',
#   'Interval': 1117.0,
#   'Category': 'Sports',
#   'Length': 594.0,
#   'Views': 83803.0,
#   'Rating': 4.81,
#   'Num_Rating': 185.0,
#   'Comments': 232.0,
#   'RelativeID': 'xJkift7F3K4'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f904'),
#   'ID': '16s-pJs69UU',
#   'Uploader': 'Naimahdancer',
#   'Interval': 476.0,
#   'Category': 'Entertainment',
#   'Length': 215.0,
#   'Views': 111214.0,
#   'Rating': 4.62,
#   'Num_Rating': 339.0,
#   'Comments': 118.0,
#   'RelativeID': 'matlu0BOmNY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f905'),
#   'ID': 'kHKefMuCqlk',
#   'Uploader': 'minidaul',
#   'Interval': 386.0,
#   'Category': 'Sports',
#   'Length': 222.0,
#   'Views': 826140.0,
#   'Rating': 4.63,
#   'Num_Rating': 772.0,
#   'Comments': 651.0,
#   'RelativeID': 'pM3GHI5xR9U'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f906'),
#   'ID': '1A1thQqUvAI',
#   'Uploader': 'colleenblueblue',
#   'Interval': 479.0,
#   'Category': 'Music',
#   'Length': 289.0,
#   'Views': 48360.0,
#   'Rating': 4.75,
#   'Num_Rating': 44.0,
#   'Comments': 18.0,
#   'RelativeID': '1504cSBhWG0'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f907'),
#   'ID': 'awVJCNMw1To',
#   'Uploader': 'JessCLevengood',
#   'Interval': 1004.0,
#   'Category': 'Music',
#   'Length': 367.0,
#   'Views': 71376.0,
#   'Rating': 4.83,
#   'Num_Rating': 207.0,
#   'Comments': 253.0,
#   'RelativeID': 'Xk8Yo4pzhWs'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f908'),
#   'ID': 'FJETon8XRxY',
#   'Uploader': 'ped666',
#   'Interval': 490.0,
#   'Category': 'Music',
#   'Length': 209.0,
#   'Views': 105878.0,
#   'Rating': 4.71,
#   'Num_Rating': 307.0,
#   'Comments': 183.0,
#   'RelativeID': 'TPUZqcibh4E'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f909'),
#   'ID': '3t8GdtYdRk0',
#   'Uploader': 'HalfaZoul',
#   'Interval': 675.0,
#   'Category': 'Music',
#   'Length': 120.0,
#   'Views': 2657650.0,
#   'Rating': 4.48,
#   'Num_Rating': 3552.0,
#   'Comments': 2714.0,
#   'RelativeID': 'tyAvaLsLFl8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f90a'),
#   'ID': 'o5t3PwKccOo',
#   'Uploader': 'EEntertainmentTV',
#   'Interval': 447.0,
#   'Category': 'Entertainment',
#   'Length': 200.0,
#   'Views': 140901.0,
#   'Rating': 4.84,
#   'Num_Rating': 297.0,
#   'Comments': 130.0,
#   'RelativeID': '2ibL1TbN1Mk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f90b'),
#   'ID': 'ype6Hw_Hmjo',
#   'Uploader': '25thNovember1970',
#   'Interval': 1006.0,
#   'Category': 'Music',
#   'Length': 306.0,
#   'Views': 14332.0,
#   'Rating': 4.92,
#   'Num_Rating': 60.0,
#   'Comments': 46.0,
#   'RelativeID': 'KvOnRdMi4OM'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f90c'),
#   'ID': 'ylzerQfIMn4',
#   'Uploader': 'mrpregnant',
#   'Interval': 511.0,
#   'Category': 'Comedy',
#   'Length': 240.0,
#   'Views': 92079.0,
#   'Rating': 4.25,
#   'Num_Rating': 528.0,
#   'Comments': 384.0,
#   'RelativeID': '0GISY0A395w'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f90d'),
#   'ID': '2sigtR16STI',
#   'Uploader': 'mrpregnant',
#   'Interval': 592.0,
#   'Category': 'Comedy',
#   'Length': 202.0,
#   'Views': 174514.0,
#   'Rating': 2.84,
#   'Num_Rating': 842.0,
#   'Comments': 602.0,
#   'RelativeID': '_dTZePy1p44'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f90e'),
#   'ID': 'uAZ7Cop0t8U',
#   'Uploader': 'mrpregnant',
#   'Interval': 890.0,
#   'Category': 'Comedy',
#   'Length': 144.0,
#   'Views': 30395.0,
#   'Rating': 4.09,
#   'Num_Rating': 440.0,
#   'Comments': 719.0,
#   'RelativeID': 'wqEvEr8xahg'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f90f'),
#   'ID': 'im7IorDZ9uY',
#   'Uploader': 'mrpregnant',
#   'Interval': 507.0,
#   'Category': 'Comedy',
#   'Length': 294.0,
#   'Views': 442233.0,
#   'Rating': 4.56,
#   'Num_Rating': 2793.0,
#   'Comments': 1930.0,
#   'RelativeID': 'mgZcf58Z9hQ'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f910'),
#   'ID': 'tVFUWgWyEtE',
#   'Uploader': 'mrpregnant',
#   'Interval': 0.0,
#   'Category': ' UNA ',
#   'Length': 179.0,
#   'Views': 19624.0,
#   'Rating': 4.26,
#   'Num_Rating': 174.0,
#   'Comments': 147.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f911'),
#   'ID': '-znZW_JuQgs',
#   'Uploader': 'mrpregnant',
#   'Interval': 585.0,
#   'Category': 'Comedy',
#   'Length': 317.0,
#   'Views': 54841.0,
#   'Rating': 4.17,
#   'Num_Rating': 492.0,
#   'Comments': 355.0,
#   'RelativeID': 'E5zfoUvct9g'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f912'),
#   'ID': 'GJZL0XVUnRE',
#   'Uploader': 'mrpregnant',
#   'Interval': 1102.0,
#   'Category': 'Comedy',
#   'Length': 186.0,
#   'Views': 12615.0,
#   'Rating': 4.39,
#   'Num_Rating': 257.0,
#   'Comments': 200.0,
#   'RelativeID': 'vK4zrqp1yS8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f913'),
#   'ID': 'O27r2zYVIhw',
#   'Uploader': 'mrpregnant',
#   'Interval': 0.0,
#   'Category': ' UNA ',
#   'Length': 300.0,
#   'Views': 87835.0,
#   'Rating': 3.53,
#   'Num_Rating': 680.0,
#   'Comments': 251.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f914'),
#   'ID': 'ha0gjt-r2Tc',
#   'Uploader': 'mrpregnant',
#   'Interval': 509.0,
#   'Category': 'Comedy',
#   'Length': 313.0,
#   'Views': 33427.0,
#   'Rating': 4.55,
#   'Num_Rating': 614.0,
#   'Comments': 324.0,
#   'RelativeID': 'F-4QKDoLBWI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f915'),
#   'ID': 'bzVy77JZX9U',
#   'Uploader': 'mrpregnant',
#   'Interval': 1077.0,
#   'Category': 'Comedy',
#   'Length': 256.0,
#   'Views': 126333.0,
#   'Rating': 4.08,
#   'Num_Rating': 675.0,
#   'Comments': 1450.0,
#   'RelativeID': 'i3x4C1fJcUk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f916'),
#   'ID': 'i-QTc3V4PEY',
#   'Uploader': 'mrpregnant',
#   'Interval': 505.0,
#   'Category': 'Comedy',
#   'Length': 69.0,
#   'Views': 12683.0,
#   'Rating': 4.28,
#   'Num_Rating': 252.0,
#   'Comments': 44.0,
#   'RelativeID': '0GISY0A395w'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f917'),
#   'ID': 'qkrvYnNpQm4',
#   'Uploader': 'mrpregnant',
#   'Interval': 541.0,
#   'Category': 'Comedy',
#   'Length': 932.0,
#   'Views': 160465.0,
#   'Rating': 4.54,
#   'Num_Rating': 1294.0,
#   'Comments': 2011.0,
#   'RelativeID': 'DpQkJ2T7zrc'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f918'),
#   'ID': 'vK4zrqp1yS8',
#   'Uploader': 'mrpregnant',
#   'Interval': 763.0,
#   'Category': 'Comedy',
#   'Length': 419.0,
#   'Views': 200489.0,
#   'Rating': 4.18,
#   'Num_Rating': 1391.0,
#   'Comments': 1615.0,
#   'RelativeID': 'pqhlG9qYsR8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f919'),
#   'ID': 'utegCEv4qkw',
#   'Uploader': 'mrpregnant',
#   'Interval': 554.0,
#   'Category': 'Comedy',
#   'Length': 300.0,
#   'Views': 15817.0,
#   'Rating': 3.94,
#   'Num_Rating': 241.0,
#   'Comments': 280.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f91a'),
#   'ID': 'ffOY69kjeSU',
#   'Uploader': 'breLloydvrnsst',
#   'Interval': 1135.0,
#   'Category': 'Comedy',
#   'Length': 45.0,
#   'Views': 387.0,
#   'Rating': 1.3,
#   'Num_Rating': 53.0,
#   'Comments': 22.0,
#   'RelativeID': 'nKA7iTE3s6A'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f91b'),
#   'ID': 'yp-i6L_NRPM',
#   'Uploader': 'AndaleTheGreat41',
#   'Interval': 1135.0,
#   'Category': 'Comedy',
#   'Length': 14.0,
#   'Views': 221.0,
#   'Rating': 1.56,
#   'Num_Rating': 32.0,
#   'Comments': 7.0,
#   'RelativeID': 'nKA7iTE3s6A'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f91c'),
#   'ID': 'wUsG23QyaCk',
#   'Uploader': 'davoodnpussy',
#   'Interval': 1135.0,
#   'Category': 'Comedy',
#   'Length': 47.0,
#   'Views': 251.0,
#   'Rating': 1.47,
#   'Num_Rating': 51.0,
#   'Comments': 19.0,
#   'RelativeID': 'nKA7iTE3s6A'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f91d'),
#   'ID': 'mRHGKGRlz-Q',
#   'Uploader': 'JamesNintendoNerd',
#   'Interval': 1099.0,
#   'Category': 'Comedy',
#   'Length': 57.0,
#   'Views': 195618.0,
#   'Rating': 4.86,
#   'Num_Rating': 2469.0,
#   'Comments': 1581.0,
#   'RelativeID': 's0KuesK9RFk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f91e'),
#   'ID': 'wKXAEVO4htE',
#   'Uploader': 'arthurhapsody',
#   'Interval': 870.0,
#   'Category': 'Entertainment',
#   'Length': 425.0,
#   'Views': 29972.0,
#   'Rating': 4.77,
#   'Num_Rating': 214.0,
#   'Comments': 107.0,
#   'RelativeID': 'LzLdPYu3RLQ'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f91f'),
#   'ID': 'HUOHibEbzHE',
#   'Uploader': 'Jirron',
#   'Interval': 845.0,
#   'Category': 'Music',
#   'Length': 111.0,
#   'Views': 86731.0,
#   'Rating': 4.69,
#   'Num_Rating': 447.0,
#   'Comments': 290.0,
#   'RelativeID': 'reG6g1iMd38'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f920'),
#   'ID': '4RqiI4JdGJE',
#   'Uploader': 'JamesNintendoNerd',
#   'Interval': 1071.0,
#   'Category': 'Comedy',
#   'Length': 37.0,
#   'Views': 127743.0,
#   'Rating': 4.77,
#   'Num_Rating': 1235.0,
#   'Comments': 785.0,
#   'RelativeID': 'WuJ9ZeAaf8k'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f921'),
#   'ID': 'LW78tWxjdPA',
#   'Uploader': 'JamesNintendoNerd',
#   'Interval': 1114.0,
#   'Category': 'Comedy',
#   'Length': 54.0,
#   'Views': 92279.0,
#   'Rating': 4.87,
#   'Num_Rating': 1446.0,
#   'Comments': 746.0,
#   'RelativeID': 'MiQE_Lb801U'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f922'),
#   'ID': 'Np2JTCX6H40',
#   'Uploader': 'MasterOfCards',
#   'Interval': 884.0,
#   'Category': 'Entertainment',
#   'Length': 200.0,
#   'Views': 75198.0,
#   'Rating': 4.48,
#   'Num_Rating': 631.0,
#   'Comments': 571.0,
#   'RelativeID': 'kBVmfIUR1DA'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f923'),
#   'ID': 'h2maEE7yodQ',
#   'Uploader': 'JamesNintendoNerd',
#   'Interval': 1009.0,
#   'Category': 'Entertainment',
#   'Length': 205.0,
#   'Views': 168148.0,
#   'Rating': 4.81,
#   'Num_Rating': 2290.0,
#   'Comments': 1465.0,
#   'RelativeID': 'KWJv1vvtPao'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f924'),
#   'ID': 'p3KqyCDaH28',
#   'Uploader': 'fabsbento',
#   'Interval': 1123.0,
#   'Category': 'Comedy',
#   'Length': 545.0,
#   'Views': 949.0,
#   'Rating': 5.0,
#   'Num_Rating': 8.0,
#   'Comments': 5.0,
#   'RelativeID': '0z4bEYbbEJ4'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f925'),
#   'ID': 'y_2jJS_BAh8',
#   'Uploader': 'DukeNukem3DO',
#   'Interval': 1029.0,
#   'Category': 'Entertainment',
#   'Length': 324.0,
#   'Views': 7895.0,
#   'Rating': 3.86,
#   'Num_Rating': 90.0,
#   'Comments': 65.0,
#   'RelativeID': 'n1qoESYDwPY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f926'),
#   'ID': 'cRT3tV9VdbU',
#   'Uploader': 'cloud8745',
#   'Interval': 1121.0,
#   'Category': 'People & Blogs',
#   'Length': 508.0,
#   'Views': 6378.0,
#   'Rating': 4.62,
#   'Num_Rating': 253.0,
#   'Comments': 131.0,
#   'RelativeID': '0ZNB_fktW4k'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f927'),
#   'ID': 'i-6IDRAFUtw',
#   'Uploader': 'UL05ST',
#   'Interval': 1055.0,
#   'Category': 'Music',
#   'Length': 172.0,
#   'Views': 4483.0,
#   'Rating': 4.35,
#   'Num_Rating': 20.0,
#   'Comments': 19.0,
#   'RelativeID': 'MYDuy7wM8Gk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f928'),
#   'ID': 'S-6sdlftpv8',
#   'Uploader': 'DinnerItBurns',
#   'Interval': 1067.0,
#   'Category': 'Comedy',
#   'Length': 595.0,
#   'Views': 5399.0,
#   'Rating': 4.6,
#   'Num_Rating': 72.0,
#   'Comments': 55.0,
#   'RelativeID': 'sDymphHPJo0'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f929'),
#   'ID': 'K8OVhweDZKA',
#   'Uploader': 'webjunkpoop',
#   'Interval': 910.0,
#   'Category': 'Comedy',
#   'Length': 399.0,
#   'Views': 20256.0,
#   'Rating': 4.34,
#   'Num_Rating': 111.0,
#   'Comments': 83.0,
#   'RelativeID': 'Z2QC1O8XQJI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f92a'),
#   'ID': 'E7OKDwX4Auw',
#   'Uploader': 'JamesNintendoNerd',
#   'Interval': 969.0,
#   'Category': 'Comedy',
#   'Length': 706.0,
#   'Views': 175886.0,
#   'Rating': 4.74,
#   'Num_Rating': 2989.0,
#   'Comments': 1014.0,
#   'RelativeID': '1raUvGNbZFg'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f92b'),
#   'ID': 'kGpviK7Lu20',
#   'Uploader': 'vegeta273',
#   'Interval': 876.0,
#   'Category': 'Comedy',
#   'Length': 419.0,
#   'Views': 21913.0,
#   'Rating': 4.64,
#   'Num_Rating': 182.0,
#   'Comments': 153.0,
#   'RelativeID': 'td00Xk6uUD8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f92c'),
#   'ID': 'td00Xk6uUD8',
#   'Uploader': 'vegeta273',
#   'Interval': 906.0,
#   'Category': 'Comedy',
#   'Length': 414.0,
#   'Views': 10347.0,
#   'Rating': 4.73,
#   'Num_Rating': 108.0,
#   'Comments': 98.0,
#   'RelativeID': 'kGpviK7Lu20'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f92d'),
#   'ID': 'muaTrM7Ouxw',
#   'Uploader': 'SonicXisnow2009',
#   'Interval': 1095.0,
#   'Category': 'Entertainment',
#   'Length': 597.0,
#   'Views': 736.0,
#   'Rating': 5.0,
#   'Num_Rating': 4.0,
#   'Comments': 2.0,
#   'RelativeID': 'FvWuy7p5mZE'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f92e'),
#   'ID': 'yYc9bk2muyw',
#   'Uploader': 'devttt',
#   'Interval': 1135.0,
#   'Category': 'News & Politics',
#   'Length': 407.0,
#   'Views': 392.0,
#   'Rating': 4.07,
#   'Num_Rating': 30.0,
#   'Comments': 10.0,
#   'RelativeID': 'acHkXqik_Bo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f92f'),
#   'ID': 'F76IkRohiow',
#   'Uploader': '2008freetibet',
#   'Interval': 1131.0,
#   'Category': 'News & Politics',
#   'Length': 131.0,
#   'Views': 1853.0,
#   'Rating': 3.53,
#   'Num_Rating': 36.0,
#   'Comments': 23.0,
#   'RelativeID': 'DlbIyZ0l0RY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f930'),
#   'ID': '2I2bvs3uZ4c',
#   'Uploader': nan,
#   'Interval': nan,
#   'Category': nan,
#   'Length': nan,
#   'Views': nan,
#   'Rating': nan,
#   'Num_Rating': nan,
#   'Comments': nan,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f931'),
#   'ID': 'h8FMNtTw24o',
#   'Uploader': 'cmforum',
#   'Interval': 1127.0,
#   'Category': 'News & Politics',
#   'Length': 178.0,
#   'Views': 19946.0,
#   'Rating': 4.75,
#   'Num_Rating': 434.0,
#   'Comments': 276.0,
#   'RelativeID': 'x9QNKB34cJo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f932'),
#   'ID': 'TR-ekaXzaWA',
#   'Uploader': 'Tibetan72',
#   'Interval': 1135.0,
#   'Category': 'News & Politics',
#   'Length': 407.0,
#   'Views': 100.0,
#   'Rating': 4.64,
#   'Num_Rating': 11.0,
#   'Comments': 4.0,
#   'RelativeID': 'tr46ApMFXzk'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f933'),
#   'ID': 'Oi0NB6ENnF4',
#   'Uploader': 'journeymanpictures',
#   'Interval': 996.0,
#   'Category': 'News & Politics',
#   'Length': 1044.0,
#   'Views': 1856.0,
#   'Rating': 3.11,
#   'Num_Rating': 19.0,
#   'Comments': 17.0,
#   'RelativeID': '0VRneGYpaXc'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f934'),
#   'ID': 'huVb7FH87Wk',
#   'Uploader': 'mayyoubekind',
#   'Interval': 1132.0,
#   'Category': 'News & Politics',
#   'Length': 433.0,
#   'Views': 807.0,
#   'Rating': 1.7,
#   'Num_Rating': 40.0,
#   'Comments': 23.0,
#   'RelativeID': 'GKR1v0QwXrM'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f935'),
#   'ID': 'vv7jdRswKSM',
#   'Uploader': 'sonamsam23',
#   'Interval': 1127.0,
#   'Category': 'News & Politics',
#   'Length': 250.0,
#   'Views': 1420.0,
#   'Rating': 3.33,
#   'Num_Rating': 12.0,
#   'Comments': 15.0,
#   'RelativeID': 'MAuKv6Qz7SY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f936'),
#   'ID': 'ou_b4qq1REU',
#   'Uploader': 'kgb23lyc',
#   'Interval': 1119.0,
#   'Category': 'News & Politics',
#   'Length': 64.0,
#   'Views': 1362.0,
#   'Rating': 3.5,
#   'Num_Rating': 8.0,
#   'Comments': 13.0,
#   'RelativeID': 'jqEq5zUNgxo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f937'),
#   'ID': 'oG21V-JwWYs',
#   'Uploader': 'UTEEngineer',
#   'Interval': 1128.0,
#   'Category': 'News & Politics',
#   'Length': 579.0,
#   'Views': 25430.0,
#   'Rating': 4.27,
#   'Num_Rating': 494.0,
#   'Comments': 596.0,
#   'RelativeID': 'uSQnK5FcKas'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f938'),
#   'ID': 'uqoRF9bu8VI',
#   'Uploader': 'squishydemon',
#   'Interval': 1127.0,
#   'Category': 'News & Politics',
#   'Length': 46.0,
#   'Views': 1021.0,
#   'Rating': 3.0,
#   'Num_Rating': 4.0,
#   'Comments': 16.0,
#   'RelativeID': 'rhP-MWXtAGA'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f939'),
#   'ID': 'uzv-gkiSjEk',
#   'Uploader': 'TAIYOWHALE',
#   'Interval': 1124.0,
#   'Category': 'News & Politics',
#   'Length': 156.0,
#   'Views': 20435.0,
#   'Rating': 3.99,
#   'Num_Rating': 78.0,
#   'Comments': 389.0,
#   'RelativeID': 'GJP1c9CssZI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f93a'),
#   'ID': 'xwGX5Fx7o8E',
#   'Uploader': 'HHK17',
#   'Interval': 1133.0,
#   'Category': 'News & Politics',
#   'Length': 599.0,
#   'Views': 211.0,
#   'Rating': 3.33,
#   'Num_Rating': 12.0,
#   'Comments': 14.0,
#   'RelativeID': 'mb-ezekCmR0'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f93b'),
#   'ID': '-Dd4v9yA4FQ',
#   'Uploader': 'sonamsam23',
#   'Interval': 1127.0,
#   'Category': 'News & Politics',
#   'Length': 122.0,
#   'Views': 634.0,
#   'Rating': 3.8,
#   'Num_Rating': 10.0,
#   'Comments': 14.0,
#   'RelativeID': 'vv7jdRswKSM'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f93c'),
#   'ID': 'EjN3bdvKGiw',
#   'Uploader': 'NewsRevue',
#   'Interval': 1127.0,
#   'Category': 'News & Politics',
#   'Length': 149.0,
#   'Views': 1458.0,
#   'Rating': 3.0,
#   'Num_Rating': 7.0,
#   'Comments': 33.0,
#   'RelativeID': 'U65CJuMB268'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f93d'),
#   'ID': 'pcfQ8GA063c',
#   'Uploader': 'jijtube',
#   'Interval': 1124.0,
#   'Category': 'News & Politics',
#   'Length': 130.0,
#   'Views': 33998.0,
#   'Rating': 3.72,
#   'Num_Rating': 129.0,
#   'Comments': 671.0,
#   'RelativeID': 'onB7pIT4mKo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f93e'),
#   'ID': 'qB_YqEk15e0',
#   'Uploader': 'bharatamata',
#   'Interval': 1126.0,
#   'Category': 'News & Politics',
#   'Length': 129.0,
#   'Views': 4123.0,
#   'Rating': 2.82,
#   'Num_Rating': 101.0,
#   'Comments': 245.0,
#   'RelativeID': 'pcfQ8GA063c'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f93f'),
#   'ID': 'Rql5wjKhzZM',
#   'Uploader': nan,
#   'Interval': nan,
#   'Category': nan,
#   'Length': nan,
#   'Views': nan,
#   'Rating': nan,
#   'Num_Rating': nan,
#   'Comments': nan,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f940'),
#   'ID': 'Hv3Yq3rpQB8',
#   'Uploader': nan,
#   'Interval': nan,
#   'Category': nan,
#   'Length': nan,
#   'Views': nan,
#   'Rating': nan,
#   'Num_Rating': nan,
#   'Comments': nan,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f941'),
#   'ID': 'XsJBNkAn1Ws',
#   'Uploader': nan,
#   'Interval': nan,
#   'Category': nan,
#   'Length': nan,
#   'Views': nan,
#   'Rating': nan,
#   'Num_Rating': nan,
#   'Comments': nan,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f942'),
#   'ID': 'O3SOfHiaLCc',
#   'Uploader': 'FreeWingz',
#   'Interval': 538.0,
#   'Category': 'Comedy',
#   'Length': 414.0,
#   'Views': 1263.0,
#   'Rating': 4.2,
#   'Num_Rating': 50.0,
#   'Comments': 58.0,
#   'RelativeID': 'SGP_RpS4YSM'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f943'),
#   'ID': 'sHwAB4RokrA',
#   'Uploader': 'agentsmith21',
#   'Interval': 772.0,
#   'Category': 'Music',
#   'Length': 241.0,
#   'Views': 331.0,
#   'Rating': 4.67,
#   'Num_Rating': 9.0,
#   'Comments': 19.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f944'),
#   'ID': 'PHf2g_4TyDY',
#   'Uploader': 'Bigbrando99',
#   'Interval': 998.0,
#   'Category': 'Sports',
#   'Length': 131.0,
#   'Views': 4052.0,
#   'Rating': 4.64,
#   'Num_Rating': 22.0,
#   'Comments': 22.0,
#   'RelativeID': 'nSft20TiMlA'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f945'),
#   'ID': 'DlEgO89LiIw',
#   'Uploader': 'live2bshiv',
#   'Interval': 970.0,
#   'Category': 'Comedy',
#   'Length': 140.0,
#   'Views': 189.0,
#   'Rating': 1.0,
#   'Num_Rating': 1.0,
#   'Comments': 0.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f946'),
#   'ID': 'o3eBdSlQIp4',
#   'Uploader': 'chaseemery',
#   'Interval': 975.0,
#   'Category': 'Music',
#   'Length': 282.0,
#   'Views': 1346.0,
#   'Rating': 4.67,
#   'Num_Rating': 12.0,
#   'Comments': 10.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f947'),
#   'ID': 'xQv4K2rO0O0',
#   'Uploader': 'mrules45',
#   'Interval': 962.0,
#   'Category': 'Entertainment',
#   'Length': 43.0,
#   'Views': 600.0,
#   'Rating': 2.25,
#   'Num_Rating': 12.0,
#   'Comments': 12.0,
#   'RelativeID': 'm3LF-lyQ2OA'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f948'),
#   'ID': 'bIP1V1u2q-E',
#   'Uploader': 'bucksdotcom',
#   'Interval': 1052.0,
#   'Category': 'Sports',
#   'Length': 85.0,
#   'Views': 9191.0,
#   'Rating': 5.0,
#   'Num_Rating': 19.0,
#   'Comments': 16.0,
#   'RelativeID': 'ql-fHfjBzls'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f949'),
#   'ID': 'Y9LbqKVTXMo',
#   'Uploader': 'seeso',
#   'Interval': 1004.0,
#   'Category': 'Music',
#   'Length': 166.0,
#   'Views': 7001.0,
#   'Rating': 4.88,
#   'Num_Rating': 203.0,
#   'Comments': 245.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f94a'),
#   'ID': 'iqHVh0D4e7M',
#   'Uploader': 'AssociatedPress',
#   'Interval': 1120.0,
#   'Category': 'News & Politics',
#   'Length': 82.0,
#   'Views': 9092.0,
#   'Rating': 3.71,
#   'Num_Rating': 7.0,
#   'Comments': 26.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f94b'),
#   'ID': 'zokUPp_nj_c',
#   'Uploader': 'ksalinda',
#   'Interval': 707.0,
#   'Category': 'Sports',
#   'Length': 68.0,
#   'Views': 8630.0,
#   'Rating': 5.0,
#   'Num_Rating': 6.0,
#   'Comments': 29.0,
#   'RelativeID': 'KhJtLJjJX9g'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f94c'),
#   'ID': '16D4DCduxVA',
#   'Uploader': 'kOrOne79',
#   'Interval': 842.0,
#   'Category': 'Sports',
#   'Length': 346.0,
#   'Views': 10713.0,
#   'Rating': 4.74,
#   'Num_Rating': 42.0,
#   'Comments': 13.0,
#   'RelativeID': 'LnF1YD6iXe0'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f94d'),
#   'ID': 'Rv7tbFPXXmU',
#   'Uploader': 'newzjim',
#   'Interval': 706.0,
#   'Category': 'Sports',
#   'Length': 309.0,
#   'Views': 47106.0,
#   'Rating': 3.85,
#   'Num_Rating': 60.0,
#   'Comments': 591.0,
#   'RelativeID': 'NK6odSRXPI4'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f94e'),
#   'ID': 'fUCguV4V6HY',
#   'Uploader': 'PrestonV20',
#   'Interval': 628.0,
#   'Category': 'Sports',
#   'Length': 119.0,
#   'Views': 50110.0,
#   'Rating': 4.07,
#   'Num_Rating': 54.0,
#   'Comments': 34.0,
#   'RelativeID': 'JAWFqXIAp3g'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f94f'),
#   'ID': 'E9gUcbDcd7E',
#   'Uploader': 'elgroxo',
#   'Interval': 744.0,
#   'Category': 'Comedy',
#   'Length': 268.0,
#   'Views': 268631.0,
#   'Rating': 4.51,
#   'Num_Rating': 926.0,
#   'Comments': 1004.0,
#   'RelativeID': '5QTx8454zQw'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f950'),
#   'ID': 'ZYryffNvDaU',
#   'Uploader': 'puprock2975',
#   'Interval': 986.0,
#   'Category': 'Sports',
#   'Length': 478.0,
#   'Views': 7853.0,
#   'Rating': 5.0,
#   'Num_Rating': 22.0,
#   'Comments': 21.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f951'),
#   'ID': 'AkYFKuGJEsE',
#   'Uploader': 'puprock2975',
#   'Interval': 987.0,
#   'Category': 'Sports',
#   'Length': 460.0,
#   'Views': 5734.0,
#   'Rating': 5.0,
#   'Num_Rating': 19.0,
#   'Comments': 12.0,
#   'RelativeID': 'ZYryffNvDaU'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f952'),
#   'ID': 'l6-J82_3utA',
#   'Uploader': '1EDmanLV',
#   'Interval': 1122.0,
#   'Category': 'Sports',
#   'Length': 58.0,
#   'Views': 2896.0,
#   'Rating': 5.0,
#   'Num_Rating': 4.0,
#   'Comments': 10.0,
#   'RelativeID': 'Vz6icPtNwZE'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f953'),
#   'ID': 'GAce3GwmyLg',
#   'Uploader': 'Brooky217',
#   'Interval': 497.0,
#   'Category': 'Music',
#   'Length': 90.0,
#   'Views': 3632.0,
#   'Rating': 4.18,
#   'Num_Rating': 11.0,
#   'Comments': 5.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f954'),
#   'ID': 'Zs4H9Itl40c',
#   'Uploader': 'dinxbeau',
#   'Interval': 1104.0,
#   'Category': 'Sports',
#   'Length': 150.0,
#   'Views': 7962.0,
#   'Rating': 5.0,
#   'Num_Rating': 12.0,
#   'Comments': 28.0,
#   'RelativeID': 'w9EHgzekwCE'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f955'),
#   'ID': 'R08Nxax_jsM',
#   'Uploader': 'xeenslayer',
#   'Interval': 1045.0,
#   'Category': 'Entertainment',
#   'Length': 513.0,
#   'Views': 1040.0,
#   'Rating': 4.17,
#   'Num_Rating': 6.0,
#   'Comments': 8.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f956'),
#   'ID': 'qhAnSGeTpz4',
#   'Uploader': 'iRespond2U',
#   'Interval': 1135.0,
#   'Category': 'Comedy',
#   'Length': 80.0,
#   'Views': 210.0,
#   'Rating': 1.67,
#   'Num_Rating': 12.0,
#   'Comments': 48.0,
#   'RelativeID': '1OF20VB_CMA'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6f957'),
#   'ID': 'mqgY3vx6DCM',
#   'Uploader': '1mResponder',
#   'Interval': 1135.0,
#   'Category': 'Comedy',
#   'Length': 54.0,
#   'Views': 224.0,
#   'Rating': 1.8,
#   'Num_Rating': 5.0,
#   'Comments': 14.0,
#   'RelativeID': '1OF20VB_CMA'},
# ...
#   'Num_Rating': 663.0,
#   'Comments': 647.0,
#   'RelativeID': 'V2wmrbsDg9A'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc59'),
#   'ID': 'FdBDfUCpBFg',
#   'Uploader': 'sonicat',
#   'Interval': 548.0,
#   'Category': 'Music',
#   'Length': 348.0,
#   'Views': 182569.0,
#   'Rating': 4.77,
#   'Num_Rating': 417.0,
#   'Comments': 483.0,
#   'RelativeID': 'IHy5tFI05js'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc5a'),
#   'ID': 'cb_9uH-ELJE',
#   'Uploader': 'RicBNH',
#   'Interval': 430.0,
#   'Category': 'Music',
#   'Length': 220.0,
#   'Views': 315143.0,
#   'Rating': 4.79,
#   'Num_Rating': 930.0,
#   'Comments': 713.0,
#   'RelativeID': 'ytNoiQ8LkS8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc5b'),
#   'ID': 'Bn7exBrCiUI',
#   'Uploader': 'RicBNH',
#   'Interval': 425.0,
#   'Category': 'Music',
#   'Length': 297.0,
#   'Views': 458325.0,
#   'Rating': 4.84,
#   'Num_Rating': 1339.0,
#   'Comments': 570.0,
#   'RelativeID': 'jkje4FiH9Qc'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc5c'),
#   'ID': 'qH3GHaJF_QI',
#   'Uploader': 'bellhydeist',
#   'Interval': 640.0,
#   'Category': 'Music',
#   'Length': 276.0,
#   'Views': 47780.0,
#   'Rating': 4.94,
#   'Num_Rating': 201.0,
#   'Comments': 122.0,
#   'RelativeID': 'j5NDwfk-ah8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc5d'),
#   'ID': 'ChJYioZ4nXs',
#   'Uploader': 'ellebelle1988',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 277.0,
#   'Views': 269.0,
#   'Rating': 5.0,
#   'Num_Rating': 8.0,
#   'Comments': 9.0,
#   'RelativeID': '6Cq-S5hGkPo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc5e'),
#   'ID': 'c3m_m4mZ-Uc',
#   'Uploader': 'aXXoJadie',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 446.0,
#   'Views': 184.0,
#   'Rating': 5.0,
#   'Num_Rating': 4.0,
#   'Comments': 4.0,
#   'RelativeID': '6Cq-S5hGkPo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc5f'),
#   'ID': 'NjwW09AAr5k',
#   'Uploader': 'Proceedwithcaution',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 122.0,
#   'Views': 161.0,
#   'Rating': 5.0,
#   'Num_Rating': 7.0,
#   'Comments': 9.0,
#   'RelativeID': '6Cq-S5hGkPo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc60'),
#   'ID': 'I_iWms-0h3U',
#   'Uploader': 'MyLifeAsLiza',
#   'Interval': 1134.0,
#   'Category': 'People & Blogs',
#   'Length': 45.0,
#   'Views': 202.0,
#   'Rating': 5.0,
#   'Num_Rating': 5.0,
#   'Comments': 2.0,
#   'RelativeID': '6Cq-S5hGkPo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc61'),
#   'ID': 'a8Ist4c9S3Q',
#   'Uploader': 'Aceswolf',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 77.0,
#   'Views': 93.0,
#   'Rating': 5.0,
#   'Num_Rating': 2.0,
#   'Comments': 3.0,
#   'RelativeID': '6Cq-S5hGkPo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc62'),
#   'ID': 'nV6KEbPKc0k',
#   'Uploader': 'FennixRisen',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 240.0,
#   'Views': 77.0,
#   'Rating': 5.0,
#   'Num_Rating': 5.0,
#   'Comments': 3.0,
#   'RelativeID': 'mtOy39CaOPM'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc63'),
#   'ID': 'mtOy39CaOPM',
#   'Uploader': 'GymMidget415',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 59.0,
#   'Views': 279.0,
#   'Rating': 4.93,
#   'Num_Rating': 14.0,
#   'Comments': 11.0,
#   'RelativeID': 'E4hFivbtSvs'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc64'),
#   'ID': 'GokPK5sUBrw',
#   'Uploader': 'mspulido4',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 50.0,
#   'Views': 85.0,
#   'Rating': 5.0,
#   'Num_Rating': 2.0,
#   'Comments': 4.0,
#   'RelativeID': '6Cq-S5hGkPo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc65'),
#   'ID': 'Ohkr-Xi8GlQ',
#   'Uploader': 'soozfive',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 108.0,
#   'Views': 117.0,
#   'Rating': 4.76,
#   'Num_Rating': 17.0,
#   'Comments': 12.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc66'),
#   'ID': 'o2omZSr6a88',
#   'Uploader': 'aXXoJadie',
#   'Interval': 1136.0,
#   'Category': 'People & Blogs',
#   'Length': 533.0,
#   'Views': 9.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 3.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc67'),
#   'ID': 'd4FTxpyoKYE',
#   'Uploader': 'pipsipirate',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 232.0,
#   'Views': 37.0,
#   'Rating': 5.0,
#   'Num_Rating': 3.0,
#   'Comments': 1.0,
#   'RelativeID': 'fsFVt7Dvb94'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc68'),
#   'ID': 'ENUmfc4v0DE',
#   'Uploader': 'squirt1993',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 124.0,
#   'Views': 54.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 1.0,
#   'RelativeID': '6Cq-S5hGkPo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc69'),
#   'ID': '1SR9ztiyoug',
#   'Uploader': 'hystericredcoat',
#   'Interval': 1134.0,
#   'Category': 'People & Blogs',
#   'Length': 82.0,
#   'Views': 146.0,
#   'Rating': 5.0,
#   'Num_Rating': 10.0,
#   'Comments': 3.0,
#   'RelativeID': '6Cq-S5hGkPo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc6a'),
#   'ID': '0S_C9SK1eWw',
#   'Uploader': 'emilineC',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 84.0,
#   'Views': 187.0,
#   'Rating': 5.0,
#   'Num_Rating': 12.0,
#   'Comments': 9.0,
#   'RelativeID': '-GC-4XUjM8M'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc6b'),
#   'ID': 'mgQAhsHL3lg',
#   'Uploader': 'Orangehatten',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 250.0,
#   'Views': 113.0,
#   'Rating': 5.0,
#   'Num_Rating': 3.0,
#   'Comments': 2.0,
#   'RelativeID': 'c3m_m4mZ-Uc'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc6c'),
#   'ID': 'iqBulJCt_gk',
#   'Uploader': 'becoolsodapop',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 135.0,
#   'Views': 156.0,
#   'Rating': 4.75,
#   'Num_Rating': 8.0,
#   'Comments': 6.0,
#   'RelativeID': 'c3m_m4mZ-Uc'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc6d'),
#   'ID': 'SKQ44BS_6sY',
#   'Uploader': 'timsbro2000',
#   'Interval': 1134.0,
#   'Category': 'People & Blogs',
#   'Length': 92.0,
#   'Views': 128.0,
#   'Rating': 5.0,
#   'Num_Rating': 10.0,
#   'Comments': 6.0,
#   'RelativeID': '7D5NLnY7SOE'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc6e'),
#   'ID': 'icMd8yAZCrY',
#   'Uploader': 'kirstenreads',
#   'Interval': 1135.0,
#   'Category': 'People & Blogs',
#   'Length': 231.0,
#   'Views': 117.0,
#   'Rating': 5.0,
#   'Num_Rating': 7.0,
#   'Comments': 9.0,
#   'RelativeID': 'ChJYioZ4nXs'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc6f'),
#   'ID': 'vHqM4BYFZOk',
#   'Uploader': 'NeedaCoolUsername',
#   'Interval': 1134.0,
#   'Category': 'People & Blogs',
#   'Length': 6.0,
#   'Views': 27.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 1.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc70'),
#   'ID': 'Tx0X7jKwvx4',
#   'Uploader': 'fiveawesomegirls',
#   'Interval': 1091.0,
#   'Category': 'People & Blogs',
#   'Length': 245.0,
#   'Views': 10712.0,
#   'Rating': 4.91,
#   'Num_Rating': 385.0,
#   'Comments': 303.0,
#   'RelativeID': 'HQkN2JjKpyE'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc71'),
#   'ID': 'vxj1RDbp_iE',
#   'Uploader': 'TheOnion',
#   'Interval': 1115.0,
#   'Category': 'News & Politics',
#   'Length': 82.0,
#   'Views': 73851.0,
#   'Rating': 4.9,
#   'Num_Rating': 465.0,
#   'Comments': 230.0,
#   'RelativeID': 'viVAAy_qkx0'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc72'),
#   'ID': 'hmmAdbDF1xA',
#   'Uploader': 'TheOnion',
#   'Interval': 1112.0,
#   'Category': 'News & Politics',
#   'Length': 174.0,
#   'Views': 71427.0,
#   'Rating': 4.74,
#   'Num_Rating': 453.0,
#   'Comments': 255.0,
#   'RelativeID': 'n5pkDB7zEeo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc73'),
#   'ID': 'irp8CNj9qBI',
#   'Uploader': 'Frozentoast',
#   'Interval': 215.0,
#   'Category': 'Music',
#   'Length': 349.0,
#   'Views': 10172172.0,
#   'Rating': 4.9,
#   'Num_Rating': 43774.0,
#   'Comments': 29330.0,
#   'RelativeID': 'cxbFLYa0_bw'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc74'),
#   'ID': 'cQ7J7UjsRqg',
#   'Uploader': 'TheOnion',
#   'Interval': 1112.0,
#   'Category': 'Science & Technology',
#   'Length': 68.0,
#   'Views': 85602.0,
#   'Rating': 4.76,
#   'Num_Rating': 678.0,
#   'Comments': 768.0,
#   'RelativeID': 'Mvz_xzaMvCQ'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc75'),
#   'ID': 'JpD4NGZoPb8',
#   'Uploader': 'love0fmylife',
#   'Interval': 1083.0,
#   'Category': 'Comedy',
#   'Length': 276.0,
#   'Views': 14123.0,
#   'Rating': 1.4,
#   'Num_Rating': 93.0,
#   'Comments': 69.0,
#   'RelativeID': 'n5pkDB7zEeo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc76'),
#   'ID': 'viVAAy_qkx0',
#   'Uploader': 'TheOnion',
#   'Interval': 1115.0,
#   'Category': 'News & Politics',
#   'Length': 145.0,
#   'Views': 63027.0,
#   'Rating': 4.9,
#   'Num_Rating': 749.0,
#   'Comments': 279.0,
#   'RelativeID': 'vxj1RDbp_iE'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc77'),
#   'ID': 'Mvz_xzaMvCQ',
#   'Uploader': 'TheOnion',
#   'Interval': 1108.0,
#   'Category': 'News & Politics',
#   'Length': 128.0,
#   'Views': 99680.0,
#   'Rating': 4.81,
#   'Num_Rating': 684.0,
#   'Comments': 428.0,
#   'RelativeID': 'aotlEpmAFVQ'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc78'),
#   'ID': 'dn5f0-y71tE',
#   'Uploader': 'TheOnion',
#   'Interval': 1116.0,
#   'Category': 'News & Politics',
#   'Length': 92.0,
#   'Views': 34879.0,
#   'Rating': 4.69,
#   'Num_Rating': 215.0,
#   'Comments': 84.0,
#   'RelativeID': 'D_5nLxZVoPo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc79'),
#   'ID': 'OHVvVmUNBFc',
#   'Uploader': 'TheOnion',
#   'Interval': 1091.0,
#   'Category': 'News & Politics',
#   'Length': 88.0,
#   'Views': 146497.0,
#   'Rating': 4.62,
#   'Num_Rating': 394.0,
#   'Comments': 556.0,
#   'RelativeID': '-AeuAB_6sLo'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc7a'),
#   'ID': 'iikKzQwgBJc',
#   'Uploader': 'awesomechick520',
#   'Interval': 484.0,
#   'Category': 'Music',
#   'Length': 119.0,
#   'Views': 7043921.0,
#   'Rating': 4.86,
#   'Num_Rating': 17885.0,
#   'Comments': 8064.0,
#   'RelativeID': 'sogKUx_q7ig'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc7b'),
#   'ID': 'cxbFLYa0_bw',
#   'Uploader': 'xsniped',
#   'Interval': 330.0,
#   'Category': 'Music',
#   'Length': 297.0,
#   'Views': 4635992.0,
#   'Rating': 4.91,
#   'Num_Rating': 13314.0,
#   'Comments': 7919.0,
#   'RelativeID': 'irp8CNj9qBI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc7c'),
#   'ID': '58CJih1iYC0',
#   'Uploader': 'JAYSOMSEN',
#   'Interval': 387.0,
#   'Category': 'Entertainment',
#   'Length': 212.0,
#   'Views': 4915513.0,
#   'Rating': 4.91,
#   'Num_Rating': 17008.0,
#   'Comments': 11093.0,
#   'RelativeID': 'cxbFLYa0_bw'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc7d'),
#   'ID': '73Pbs8hKCEc',
#   'Uploader': 'TheOnion',
#   'Interval': 1107.0,
#   'Category': 'Science & Technology',
#   'Length': 115.0,
#   'Views': 43212.0,
#   'Rating': 4.8,
#   'Num_Rating': 368.0,
#   'Comments': 167.0,
#   'RelativeID': 'aotlEpmAFVQ'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc7e'),
#   'ID': '4ADh8Fs3YdU',
#   'Uploader': 'VVasp',
#   'Interval': 524.0,
#   'Category': 'Music',
#   'Length': 255.0,
#   'Views': 4226122.0,
#   'Rating': 4.91,
#   'Num_Rating': 10512.0,
#   'Comments': 5883.0,
#   'RelativeID': 'irp8CNj9qBI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc7f'),
#   'ID': 'LBrDzZCOQtI',
#   'Uploader': 'TheOnion',
#   'Interval': 1105.0,
#   'Category': 'News & Politics',
#   'Length': 164.0,
#   'Views': 100574.0,
#   'Rating': 4.9,
#   'Num_Rating': 978.0,
#   'Comments': 586.0,
#   'RelativeID': 'aotlEpmAFVQ'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc80'),
#   'ID': 'MMz-wi50ACU',
#   'Uploader': 'ringostarrkicksass',
#   'Interval': 285.0,
#   'Category': 'Entertainment',
#   'Length': 184.0,
#   'Views': 2488790.0,
#   'Rating': 4.9,
#   'Num_Rating': 7243.0,
#   'Comments': 5855.0,
#   'RelativeID': '58CJih1iYC0'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc81'),
#   'ID': 'aotlEpmAFVQ',
#   'Uploader': 'TheOnion',
#   'Interval': 1105.0,
#   'Category': 'News & Politics',
#   'Length': 111.0,
#   'Views': 70832.0,
#   'Rating': 4.86,
#   'Num_Rating': 680.0,
#   'Comments': 360.0,
#   'RelativeID': 'Mvz_xzaMvCQ'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc82'),
#   'ID': 'Zo52T7uKOJU',
#   'Uploader': 'horaciocambeiro',
#   'Interval': 465.0,
#   'Category': 'Music',
#   'Length': 239.0,
#   'Views': 2995664.0,
#   'Rating': 4.92,
#   'Num_Rating': 9592.0,
#   'Comments': 4639.0,
#   'RelativeID': '4ADh8Fs3YdU'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc83'),
#   'ID': '6RIQIa_8AVI',
#   'Uploader': 'KatrPictures',
#   'Interval': 1112.0,
#   'Category': 'Entertainment',
#   'Length': 398.0,
#   'Views': 791855.0,
#   'Rating': 3.29,
#   'Num_Rating': 475.0,
#   'Comments': 309.0,
#   'RelativeID': '4XfMhuJqqvI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc84'),
#   'ID': 'b-rOd6EeCPI',
#   'Uploader': 'thecoroters',
#   'Interval': 1124.0,
#   'Category': 'Comedy',
#   'Length': 126.0,
#   'Views': 99243.0,
#   'Rating': 4.65,
#   'Num_Rating': 299.0,
#   'Comments': 203.0,
#   'RelativeID': 'iikKzQwgBJc'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc85'),
#   'ID': 'PSCkBf24acQ',
#   'Uploader': 'WoodElf',
#   'Interval': 343.0,
#   'Category': 'Entertainment',
#   'Length': 211.0,
#   'Views': 41574.0,
#   'Rating': 4.41,
#   'Num_Rating': 80.0,
#   'Comments': 42.0,
#   'RelativeID': 'F9CNSGwvGcY'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc86'),
#   'ID': 'llg9LbxzAmU',
#   'Uploader': 'roy791202',
#   'Interval': 834.0,
#   'Category': 'Film & Animation',
#   'Length': 347.0,
#   'Views': 239.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 0.0,
#   'RelativeID': 'TswECq-0Nt4'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc87'),
#   'ID': 'wvsw63bZ0jQ',
#   'Uploader': 'chrismagovern',
#   'Interval': 364.0,
#   'Category': 'Film & Animation',
#   'Length': 116.0,
#   'Views': 128386.0,
#   'Rating': 4.36,
#   'Num_Rating': 281.0,
#   'Comments': 120.0,
#   'RelativeID': 'IA4UIukJI7U'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc88'),
#   'ID': 'BylF9KL5UDk',
#   'Uploader': 'AshantiReagansntta',
#   'Interval': 1135.0,
#   'Category': 'Film & Animation',
#   'Length': 244.0,
#   'Views': 5.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 0.0,
#   'RelativeID': 'NzVDm9sZWGI'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc89'),
#   'ID': 'OcAmiEtecUE',
#   'Uploader': 'radiotoronto',
#   'Interval': 1071.0,
#   'Category': 'Music',
#   'Length': 269.0,
#   'Views': 218.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 0.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc8a'),
#   'ID': 'txhkZY3GbCI',
#   'Uploader': 'BlueAeon',
#   'Interval': 1122.0,
#   'Category': 'Film & Animation',
#   'Length': 30.0,
#   'Views': 9.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 0.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc8b'),
#   'ID': 'Nw9XPaByX3M',
#   'Uploader': 'jasoto',
#   'Interval': 958.0,
#   'Category': 'Film & Animation',
#   'Length': 85.0,
#   'Views': 435.0,
#   'Rating': 0.0,
#   'Num_Rating': 0.0,
#   'Comments': 0.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc8c'),
#   'ID': 'ZZtWiWYT85g',
#   'Uploader': 'bananartista',
#   'Interval': 1103.0,
#   'Category': 'Film & Animation',
#   'Length': 129.0,
#   'Views': 1039.0,
#   'Rating': 4.0,
#   'Num_Rating': 4.0,
#   'Comments': 2.0,
#   'RelativeID': '7nIiTqcYMyg'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc8d'),
#   'ID': 'wUZMpKaEX0I',
#   'Uploader': 'jasoto',
#   'Interval': 959.0,
#   'Category': 'Film & Animation',
#   'Length': 105.0,
#   'Views': 3050.0,
#   'Rating': 2.33,
#   'Num_Rating': 3.0,
#   'Comments': 0.0,
#   'RelativeID': 'oi8zOPda7LU'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc8e'),
#   'ID': '3d-utUWRXBk',
#   'Uploader': 'ilbon007musa',
#   'Interval': 1019.0,
#   'Category': 'Music',
#   'Length': 318.0,
#   'Views': 2436.0,
#   'Rating': 5.0,
#   'Num_Rating': 1.0,
#   'Comments': 0.0,
#   'RelativeID': nan},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc8f'),
#   'ID': 'd2xLtPzo87o',
#   'Uploader': 'tanner1227',
#   'Interval': 968.0,
#   'Category': 'Entertainment',
#   'Length': 168.0,
#   'Views': 1496.0,
#   'Rating': 4.33,
#   'Num_Rating': 15.0,
#   'Comments': 29.0,
#   'RelativeID': '0EjCoYe1_Ns'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc90'),
#   'ID': 'o23Gf5mHif0',
#   'Uploader': 'ShdwHg',
#   'Interval': 1072.0,
#   'Category': 'Entertainment',
#   'Length': 137.0,
#   'Views': 43577.0,
#   'Rating': 4.71,
#   'Num_Rating': 103.0,
#   'Comments': 272.0,
#   'RelativeID': '7v7EULHySw8'},
#  {'_id': ObjectId('5da2be3b1dc1408ebbe6fc91'),
#   'ID': 'GyCpoZKQGfo',
#   'Uploader': 'smitty0205',
#   'Interval': 1040.0,
#   'Category': 'Entertainment',
#   'Length': 374.0,
#   'Views': 1196.0,
#   'Rating': 4.44,
#   'Num_Rating': 16.0,
#   'Comments': 34.0,
#   'RelativeID': 'nOickA0tiEY'},
#  ...]

# %%
x = yt.find({},{'Uploader','Rating','Category','Views'},sort = [('Rating',pymongo.DESCENDING),('Views',pymongo.DESCENDING)])
x1 = [i for i in x[0:5]]
x1[0]['Uploader']
# Out:
# 'd00d123'
