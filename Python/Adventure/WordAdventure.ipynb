# %%
key = ""
nvg = int(0)

#RULES
fwd = 'go forward go ahead go in front'
bh = 'go behind turn around'
lft = 'go left'
rgt = 'go right'
op = 'open inspect look search'
on = 'turn on'
off = 'turn off'
bk = 'go back'

#CONST
bag = []
light = 1
nav = []
lc = 0
ch = 'invalid'
nvg = 'hall'
bgo = 0
frg = 0
lo = 0
lkey = ""
bkey = ""

while key != "1 5 14 3":
#     key = int(input("Enter key"))
    if ch == 'backpack':
        if len(bag) == 0:
            print("BACKPACK is empty.")
        else:
            print("The contains of your backpack are:",bag)
            use = input('Do you use anything from the BACKPACK (Y/N)?')
            if use == 'Y':
                bch = input("What do you use…?")
                if bch == 'marksheet' and bch in bag:
                    print('The marksheet shows the grade A and the percentage 91.1.')
                if bch == 'paper' and bch in bag:
                    print('The scribbling on the paper is: ‘page 394’.')
                if bch == 'note' and bch in bag:
                    print('lock = %')
                if bch == 'laptop cover'and bch in bag:
                    if lap == 1:
                        print("The laptop cover fits the laptop keyboard perfectly.")
                        lc = 1
                    else:
                        print('The laptop cover is a device that fits on the keyboard used for protection and looks')
                if bch == 'book' and bch in bag:
#                     print('The book is titled ‘Number system in programming languages’ what do you do with the book...?')
                    bookch = input('The book is titled ‘Number system in programming languages’ what do you do with the book...?')
                    if '394' in bookch:
                        print("When you turn to page 394 you find the title of the chapter to be ‘BIN->DEC->HEX’.")
                    else:
                        print("Nothing Happens")                
    lap = 0
    if nvg == 'hall':
        if light == 0:
            print("There is no light in the room.")
        else:
            print("You are trapped in a room whose only exit is a door in front of you. Behind you lies a switch panel for the lights in the entire house. To your left is the entrance to a second room, and to your right lies a pile of assorted objects. ")
        ch = input("What do you do…?")
        if ch in fwd:
            nvg = 'door'
        if ch in bh:
            nvg = 'switch'
        if ch in lft:
            nvg = 'room2'
        if ch in rgt:
            nvg = 'obj'
        continue
    if nvg == 'door':
        print("The only way to open this door is to enter the correct 4 digit code on the 16-panel touch sensor, which contains the digits 1-16.")
        k = input("Do you want to try the code…? (Y/N)?")
        if k == 'Y':
            c = [input('Enter dig '+str(i)) for i in range(4)]
            key = c[0]+" "+c[1]+" "+c[2]+" "+c[3]
        else:
            nvg = 'hall'
        continue
    if nvg == 'switch':
        print("Your options are to either turn ON or turn OFF the lights of the entire house.")
        ch = input("What do you do…?")
        if ch in on:
            print("ON")
            light = 1
        if ch in off:
            print("OFF")
            light = 0
        if ch in bk+"hall":
            nvg = 'hall'
        continue 
    if nvg == 'obj':
        if light == 0:
            if lc == 1:
                print("Since there are no lights in the house you see a faint glow coming from laptop keyboard.")#cover condition
                ch = input("What do you do…?")
                if ch in op+'laptop':
                    nvg = 'laptop2'          
            else:
                print("Since there are no lights in the house no objects are visible to you.")
                ch = input("What do you do…?")   
        else:
            print("In the pile of objects, you see a working laptop and a folder with files in it.")
            ch = input("What do you do…?")
            if ch in op+'laptop':
                nvg = 'laptop'
                 
            if ch in op+'folder'+'file':
                nvg = 'file'
        if ch in bk:
            nvg = 'hall'
        continue
    if nvg == 'laptop':
        if lo == 1:
            print("The laptop unlocks and on the screen you se a paused game on which various statistics of the player are given. Among this is the player username which is: 00010011010010.")
#             print("00010011010010")
            nvg = 'obj'
        else:
            lap = 1
            ch = input("You inspect the laptop further")
            if ch in op+'laptop':
                print("The laptop is locked by a 5-letter passcode.")
                k = input("Do you want to try the code…? (Y/N)?")
                if k == 'Y':
                    lkey = input("CODE?")
                else:
                    nvg = 'obj'
                if lkey == 'zebra':
                    print("The laptop unlocks and on the screen you se a paused game on which various statistics of the player are given. Among this is the player username which is: 00010011010010.")
#             print("00010011010010")
                    nvg = 'obj'
            if ch in bk:
                nvg = 'obj'
        continue
    if nvg == 'laptop2':
        if lo == 1:
            print("LAPTOP UNLOCKED")
            print("The laptop is already unlocked with the screen you se a paused game on which various statistics of the player are given. Among this is the player username which is: 00010011010010.")
            nvg = 'obj'
        else:
            print("When you approach the laptop you see that all of the keys are glowing except the few these keys are: ’e r z a b’. ")
            print("The laptop is locked by a 5-letter passcode.")
            k = input("Do you want to try the code…? (Y/N)?")
            if k == 'Y':
                lkey = input("CODE?")
            else:
                nvg = 'obj'
            if lkey == 'zebra':
                print("The laptop unlocks and on the screen you se a paused game on which various statistics of the player are given. Among this is the player username which is: 00010011010010.")
                nvg = 'obj'
        continue
    if nvg == 'file':
        if light == 0:
            print("Since there are no lights in the house no objects are visible to you.")
            ch = input("What do you do…?")
        else:
            print("The folder contains two documents. One is a marksheet of a certain person and the other is scrap of paper with scribbling on it.")
            ch = input("What do you do…?")
            if ch in op+'mark'+'sheet':
                bag.append('marksheet')
                print("The item is stored in your BACKPACK.")
            if ch in op+'paper':
                bag.append('paper')
                print("The item is stored in your BACKPACK.")
        if ch in bk:
            nvg = 'obj'
        continue   
    if nvg == 'room2':
        if light == 0:
            print("Since there are no lights in the house no objects are visible to you.")
            ch = input("What do you do…?")
        else:
            print("You enter the room. The room is occupied by a duffel bag at one corner and a fridge at another corner.")
            ch = input("What do you do…?")
            if ch in op+'bag':
                nvg = 'bag'
            if ch in op+'fridge':
                nvg = 'fridge' 
        if ch in bk:
            nvg = 'hall'
        continue  
    if nvg == 'bag':
        if bgo == 1:
            print("Bag is already opened.")
            nvg = 'room2'
        else:
            print("You try to open the bag, but the bag is locked. The lock has a 3-pin combination of digits.")
            k = input("Do you want to try the code…? (Y/N)?")
            if k == 'Y':
                c = [input('Enter dig '+str(i)) for i in range(3)]
                bkey = c[0]+" "+c[1]+" "+c[2]
            else:
                nvg = 'room2'
            if bkey == '9 1 1':
                print("The bag opens and inside you find a keyboard cover for a laptop and a book based on programming these items are stored in your BACKPACK.")
                bag.append('laptop cover')
                bag.append('book')
                bgo = 1
        continue
    if nvg == 'fridge':
        if frg == 1:
            print("The note is already in your BACKPACK.")
        else:
            print('On the fridge is a post-it notes with a message: ‘lock = %’.')
            ch = input("What do you do…?")
            if ch in op+"note":
                print("The item is stored in your BACKPACK.")
                bag.append('note')
            if ch in bk:
                nvg = 'room2'
        continue

print("The Door Unlocks.... YOU ARE FREE")
# Out:
# You are trapped in a room whose only exit is a door in front of you. Behind you lies a switch panel for the lights in the entire house. To your left is the entrance to a second room, and to your right lies a pile of assorted objects.
# What do you do…?forward
# The only way to open this door is to enter the correct 4 digit code on the 16-panel touch sensor, which contains the digits 1-16.
# Do you want to try the code…? (Y/N)?N
# You are trapped in a room whose only exit is a door in front of you. Behind you lies a switch panel for the lights in the entire house. To your left is the entrance to a second room, and to your right lies a pile of assorted objects.
# What do you do…?right
# In the pile of objects, you see a working laptop and a folder with files in it.
# What do you do…?laptop
# You inspect the laptop furtherlaptop
# The laptop is locked by a 5-letter passcode.
# Do you want to try the code…? (Y/N)?Y
# CODE?zebra
# ...
